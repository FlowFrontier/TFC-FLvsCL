# %% [markdown]
# # Non-IID Results

# %% [markdown]
# ## Plot client, global, and centralised model validation accuracies

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from matplotlib.lines import Line2D

def plot_validation_accuracies(rounds, client_accuracies, aggregated_accuracies, cl_accuracies, filename):
    # Replace zeros with np.nan
    for key, values in client_accuracies.items():
        client_accuracies[key] = [value if value != 0.0 else np.nan for value in values]

    # Initialize list for lines and labels
    lines = []
    labels = []

    # Create a line plot for each client
    markers = ['o', '^', 's', 'p', '*']
    for i, (client, accuracies) in enumerate(client_accuracies.items()):
        line, = plt.plot(rounds
                         , accuracies
                         , marker=markers[i]
                         , color=color_palette[i]
                         , linestyle = ":"
#                          , markersize=6
#                          , markeredgewidth=2
                         , markerfacecolor='white'
#                          , markeredgecolor=color_palette[i]
                         , alpha=0.8
                         , linewidth=1)
        lines.append(line)
        labels.append(f'Client {client}')

    # Add an empty label
    lines.append(Line2D([0], [0], marker=None, linestyle=None, color='none'))
    labels.append("")

    # Create a line plot for the aggregated model
    fl_model, = plt.plot(rounds
                         , aggregated_accuracies
                         , marker='x'
                         , linestyle='-'
                         , linewidth=1
                         , color=color_palette[i+1]
#                          , markersize=6
#                          , markeredgewidth=2
                         , markerfacecolor='white'
#                          , markeredgecolor=color_palette[i+1]
                         , alpha=1)
    lines.append(fl_model)
    labels.append('FL Model')

    # Create a line plot for the centralised model
    cl_model, = plt.plot(rounds
                         , cl_accuracies
                         , marker='x'
                         , linestyle='-'
                         , linewidth=1
                         , color=color_palette[i+2]
#                          , markersize=6
#                          , markeredgewidth=2
                         , markerfacecolor='white'
#                          , markeredgecolor=color_palette[i+2]
                         , alpha=1)
    lines.append(cl_model)
    labels.append('CL Model')

    # Add title and labels
    plt.xlabel('Epochs')
    plt.ylabel('Validation Accuracy')

    # Add a legend
    plt.legend(lines, labels,
               bbox_to_anchor=(0., 1.02, 1., .102),
               loc='lower left',
               ncol=4,
               mode="expand",
               borderaxespad=0.,
               fancybox=True,
               shadow=True)

    plt.grid(linestyle='--', linewidth=0.5)

    # Set x ticks
    plt.xticks(rounds)

    # Show the plot
    plt.tight_layout()

    # Save the plot
    plt.savefig(filename, dpi=300, bbox_inches='tight')
    
    plt.show()

    # Clear the current plot to make ready for the next plot
    plt.clf()

# Set the font and color palette
sns.set_theme(style="whitegrid")
plt.rcParams['font.family'] = 'CMU Serif'
plt.rcParams['font.size'] = '14'
color_palette = sns.color_palette("bright")

# Centralised model data
cl_accuracies = [0.9210447392562275, 0.9317841013337097, 0.9368163855761767, 0.9398154682097241, 0.941681074024416, 0.9424440759297156, 0.9451211982217204, 0.9466913061886952, 0.9483584432996965, 0.9481423329334556, 0.9499373720979465, 0.949716851316068, 0.9488744619292923, 0.9500299908263354, 0.9504533907275422, 0.9502284595300261, 0.9514589654929081, 0.9510223343447887, 0.9520587820196176, 0.9530423047067955, 0.9531525650977348, 0.9532495942417614, 0.9534921671018277, 0.9530511255380707, 0.9544007127231671, 0.9548152917930985, 0.9555518312045728, 0.9553489520852445, 0.9557811728177263, 0.9560237456777927, 0.9561781102251076, 0.9559311269494037, 0.956111953990544, 0.9564118622538988, 0.9563765789287982, 0.9562266247971208, 0.956266318537859, 0.9565706372168513, 0.957558570319667, 0.9569411121304072, 0.9584053701220803, 0.9572542516406746, 0.957404205772352, 0.95822454308094, 0.9581804389245643, 0.9585068096817444, 0.9576114953073178, 0.9583700867969798, 0.9572718933032249, 0.9582333639122151, 0.9579025827393973, 0.9580613577023499, 0.9583083409780537, 0.958480347187919, 0.
853, 0.8718255913233769, 0.8745132020776845, 0.8717579288453001, 0.8732840873545602, 0.8746509496584773, 0.8730211292863378, 0.8725955401021381, 0.8753712030829616, 0.8703350995359498, 0.8765200931696685, 0.8781828498163595, 0.13357638436557248, 0.8842546154540865, 0.8862334075790489, 0.8889811516023458, 0.8920566971588678, 0.8969129306630172, 0.8880493740462512, 0.895280602601207, 0.8984306015719173, 0.8963085579450242, 0.8969841360114083, 0.8957536280387084, 0.8977219328667113, 0.9018195623314541, 0.8985192866066409, 0.8998891194835199, 0.9009089869355893, 0.9030692873967321, 0.8981102956848906, 0.9005870389531101, 0.8998230152316838, 0.8811275728548453, 0.885554944813283, 0.888110007247989, 0.8918065539887251, 0.8932732951638019, 0.8911214412062415, 0.8909108212881808, 0.8877037171233199, 0.897414442886904, 0.893062279711177, 0.8929181557762719, 0.897575102458799, 0.8986819463311393, 0.8966671470630605, 0.8964025586079287, 0.8943805815405904, 0.9022655712243388, 0.6388372399383581, 0.8965224924748021, 0.8936303958245151, 0.9010324359269077, 0.9077892505133831, 0.9084877375932507, 0.896702770901456, 0.9013498799235852, 0.9063328493406877, 0.9135668039917407, 0.9048855587644945, 0.9081297439957041, 0.9016727307703277, 0.9131161021853028, 0.909391065670541, 0.9085075800179798, 0.9134645519540792, 0.9135278001364875, 0.9046206338708324, 0.9134963176965007, 0.9134469450525874, 0.8942902623940466, 0.9071728809424007, 0.9160416954628626]

# Training rounds
n = 5

# Create a list of all rounds
all_rounds = np.arange(1, 101)

# Select specific rounds: 1, n, 2n, 3n, ..., 100
rounds = np.append(all_rounds[0], all_rounds[n-1::n])

# Update values to match new rounds
cl_accuracies = np.append(cl_accuracies[0], cl_accuracies[n-1::n])
client_accuracies = {key: np.append(values[0], values[n-1::n]) for key, values in client_accuracies.items()}
aggregated_accuracies = np.append(aggregated_accuracies[0], aggregated_accuracies[n-1::n])

plot_validation_accuracies(rounds, client_accuracies, aggregated_accuracies, cl_accuracies, 'val-acc-non-iid-all.png')

# %% [markdown]
# ## Plot client, global, and centralised model validation losses

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from matplotlib.lines import Line2D

def plot_validation_losses(rounds, client_losses, aggregated_losses, cl_losses, filename):
    # Replace zeros with np.nan
    for key, values in client_losses.items():
        client_losses[key] = [value if value != 0.0 else np.nan for value in values]

    # Initialize list for lines and labels
    lines = []
    labels = []

    # Create a line plot for each client
    markers = ['o', '^', 's', 'p', '*']
    for i, (client, losses) in enumerate(client_losses.items()):
        line, = plt.plot(rounds
                         , losses
                         , marker=markers[i]
                         , color=color_palette[i]
                         , linestyle=':'
#                          , markersize=6
#                          , markeredgewidth=2
                         , markerfacecolor='white'
#                          , markeredgecolor=color_palette[i]
#                          , zorder=len(client_losses)-i  # setting zorder                         
                         , alpha=0.8
                         , linewidth=1)
        lines.append(line)
        labels.append(f'Client {client}')

    # Add an empty label
    lines.append(Line2D([0], [0], marker=None, linestyle=None, color='none'))
    labels.append("")

    # Create a line plot for the aggregated model
    fl_model, = plt.plot(rounds
                         , aggregated_losses
                         , marker='x'
                         , linestyle='-'
                         , linewidth=1
                         , color=color_palette[i+1]
#                          , markersize=6
#                          , markeredgewidth=2
                         , markerfacecolor='white'
#                          , markeredgecolor=color_palette[i+1]
                         , alpha=1)
    lines.append(fl_model)
    labels.append('FL Model')

    # Create a line plot for the centralised model
    cl_model, = plt.plot(rounds
                         , cl_losses
                         , marker='x'
                         , linestyle='-'
                         , linewidth=1
                         , color=color_palette[i+2]
#                          , markersize=6
#                          , markeredgewidth=2
                         , markerfacecolor='white'
#                          , markeredgecolor=color_palette[i+2]
                         , alpha=1)
    lines.append(cl_model)
    labels.append('CL Model')

    # Add title and labels
    plt.xlabel('Epochs')
    plt.ylabel('Validation Loss')

    # Add a legend
    plt.legend(lines, labels,
               bbox_to_anchor=(0., 1.02, 1., .102),
               loc='lower left',
               ncol=4,
               mode="expand",
               borderaxespad=0.,
               fancybox=True,
               shadow=True)

    plt.grid(linestyle='--', linewidth=0.5)

    # Set x ticks
    plt.xticks(rounds)

    # Show the plot
    plt.tight_layout()

    # Save the plot
    plt.savefig(filename, dpi=300, bbox_inches='tight')
    
    plt.show()

    # Clear the current plot to make ready for the next plot
    plt.clf()

# Set the font and color palette
sns.set_theme(style="whitegrid")
plt.rcParams['font.family'] = 'CMU Serif'
plt.rcParams['font.size'] = '14'
color_palette = sns.color_palette("bright")

cl_losses = [0.21439142521647178, 0.1824418762577187, 0.16677634160433083, 0.16112545886343876, 0.15476418980088727, 0.154554029553432, 0.14886774239506567, 0.14745121731829453, 0.1433074463649251, 0.14362230445766666, 0.1390900456442326, 0.13716919577264058, 0.13822223889828045, 0.1357727873487204, 0.13511253414602906, 0.1368475320393635, 0.13374907465894928, 0.13241828522810487, 0.13096857350575933, 0.13007704916974488, 0.12920513580852327, 0.12989815599295254, 0.12925607853006327, 0.13228924278763718, 0.12781758718243838, 0.12833201396671715, 0.12536647564203607, 0.12554817650566788, 0.12540268867075702, 0.1251183883484502, 0.12483240673015535, 0.12596926948467824, 0.12561233020650142, 0.12503745299235916, 0.12675796722794516, 0.12478236989151348, 0.12625815006688412, 0.12515597911740212, 0.12121254060892309, 0.12343636691291233, 0.1198145353682071, 0.12279661728074312, 0.12220445413628248, 0.12103732016116195, 0.12166080013921463, 0.1204377572257491, 0.12222243881852136, 0.11988996355408921, 0.12224981796503, 0.12064494115385453, 0.12130928741364874, 0.12097658901496072, 0.11904669459541167, 0.11941964068328385, 0.11884077410042448, 0.11727073316130253, 0.11910332217300577, 0.11886630982901762, 0.11616618307049081, 0.11571297196124705, 0.11467756746053169, 0.11636425098903105, 0.11485907347430818, 0.11615938358969036, 0.11620848381868976, 0.11727292447121358, 0.11674190409824323, 0.11532268062892836, 0.11740962510850173, 0.11739737574244, 0.11666146220398681, 0.11466670028813944, 0.11461518582671136, 0.11400543740980033, 0.11392913732315448, 0.1161406201623416, 0.1138536328260308, 0.11668255709609325, 0.11429651311468132, 0.11271753846432099, 0.11408342022668153, 0.11327657604534327, 0.11194777089418154, 0.11286678138935535, 0.11254405177454463, 0.1121698888891493, 0.11635559167975545, 0.11236111988891768, 0.11151132381210112, 0.11005239173420713, 0.10958144867499087, 0.1089325990535689, 0.11014562663076394, 0.11217783079573637, 0.1094911392930235, 0.10905413510851343, 0.10911129482536583, 0.10938399274881543, 0.11113561229762177, 0.10944428849583104]

client_losses = {
0.04327621439671107, 0.06074819823807195, 0.042125672116085776, 0.05445846444749814, 0.06759860687978818, 0.0506331383271657, 0.04363814661439035, 0.052986285707432565, 0.05747307776312494, 0.0523302281811236, 0.05435442999392057, 0.4626465108279371, 0.16180706374000844, 0.15604440660053165, 0.14337612309904157, 0.12751276727107627, 0.12196835023614676, 0.14087386841011237, 0.13195828062734388, 0.11878305683229906, 0.11363032082246648, 0.12245492033435736, 0.12108086743678396, 0.11180056023846702, 0.0994074969935995, 0.12437210104198025, 0.11379996348514163, 0.0999833383870964, 0.09736735215542715, 0.11939501664019327, 0.10729425259251166, 0.09927717514979664, 0.09084285470089196, 0.10725262465230344, 0.11474067651598746, 0.09908863107328568, 0.0958925719332766, 0.10689241297716356, 0.0983882535320533, 0.0967075528091554, 0.08689029150012066, 0.10405259864506648, 0.09854828589912236, 0.0957093796341835, 0.08746880980148242, 0.09854364089039025, 0.09736239795521762, 0.08203400096175541, 0.08030659136112767, 0.20619869507460306, 0.09072607442655009, 0.08777808756619157, 0.0778168133581671, 0.06697702049760064, 0.06059131196169736, 0.07989429654429284, 0.06243318806622583, 0.05986233181574407, 0.057563807307276234, 0.0744443342741036, 0.06873218586695536, 0.0704374476365362, 0.05770252617281373, 0.07295024453418542, 0.06562125521206583, 0.05767946320870017, 0.055829510776112264, 0.07596158704623172, 0.06364123654446387, 0.05726541504083484, 0.060131361939862966, 0.07444621986866433, 0.06133822334183255]

# Training rounds
n = 5

# Create a list of all rounds
all_rounds = np.arange(1, 101)

# Select specific rounds: 1, n, 2n, 3n, ..., 100
rounds = np.append(all_rounds[0], all_rounds[n-1::n])

# Update values to match new rounds
cl_losses = np.append(cl_losses[0], cl_losses[n-1::n])
client_losses = {key: np.append(values[0], values[n-1::n]) for key, values in client_losses.items()}
aggregated_losses = np.append(aggregated_losses[0], aggregated_losses[n-1::n])

plot_validation_losses(rounds, client_losses, aggregated_losses, cl_losses, 'val-loss-non-iid-all.png')

# %% [markdown]
# ## Plot performance metrics (precision, recall, accuracy, and F1)

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from matplotlib.lines import Line2D

def plot_validation_accuracies(rounds, fl_metrics, cl_metrics, filename):

    # Initialize list for lines and labels
    lines = []
    labels = []

    # Create a line plot for each client
    for i, (metric, values) in enumerate(fl_metrics.items()):
        line, = plt.plot(rounds
                         , values
                         , marker='x'
                         , color=color_palette[i]
#                          , markersize=6
#                          , markeredgewidth=2
                         , markerfacecolor='white'
#                          , markeredgecolor=color_palette[i]
                         , zorder=len(fl_metrics)-i  # setting zorder
                         , alpha=0.8
                         , linewidth=1)
        lines.append(line)
        if metric == "FL F1-score":
            labels.append('FL F$_1$-score')
        else:
            labels.append(metric.replace("_", "\_"))
        
    for i, (metric, values) in enumerate(cl_metrics.items()):
        line, = plt.plot(rounds
                         , values
                         , marker='o'
                         , color=color_palette[i]
#                          , markersize=6
#                          , markeredgewidth=2
                         , markerfacecolor='white'
#                          , markeredgecolor=color_palette[i]
                         , zorder=len(cl_metrics)-i  # setting zorder
                         , alpha=0.8
                         , linewidth=1)
        lines.append(line)
        if metric == "CL F1-score":
            labels.append('CL F$_1$-score')
        else:
            labels.append(metric.replace("_", "\_"))

    # Add title and labels
    plt.xlabel('Epochs')
    plt.ylabel('Metrics')

    # Add a legend
    plt.legend(lines, labels,
               bbox_to_anchor=(0., 1.02, 1., .102),
               loc='lower left',
               ncol=2,
               mode="expand",
               borderaxespad=0.,
               fancybox=True,
               shadow=True)

    plt.grid(linestyle='--', linewidth=0.5)

    # Set x ticks
    plt.xticks(rounds)

    # Show the plot
    plt.tight_layout()

    # Save the plot
    plt.savefig(filename, dpi=300, bbox_inches='tight')
    
    plt.show()

    # Clear the current plot to make ready for the next plot
    plt.clf()

# Set the font and color palette
sns.set_theme(style="whitegrid")
plt.rcParams['font.family'] = 'CMU Serif'
plt.rcParams['font.size'] = '14'
color_palette = sns.color_palette("bright")

fl_metrics = {
"FL Precision": [0.4659516244508577, 0.4956165873124886, 0.5246002674202952, 0.5521467534949259, 0.5761168674677233, 0.6025247935425593, 0.6209151198741222, 0.6455194968176164, 0.6648237947565402, 0.687201018744369, 0.7090233903117822, 0.7274605735439817, 0.7468985807685442, 0.7646439246855713, 0.7803874307518461, 0.7948346951966834, 0.8083071478298025, 0.8247893732594674, 0.8399240488209697, 0.8585116995108966, 0.8699488013464215, 0.8848542411666797, 0.8687941728757999, 0.8600928408970171, 0.8697633312947097, 0.868768616834654, 0.8653300167967445, 0.8704126236096524, 0.8720028205134915, 0.8690165574609993, 0.86959306532817, 0.8663752964014729, 0.8669027895436817, 0.8646901723763849, 0.8685476494695994, 0.8630775718316865, 0.8751595116456923, 0.8708653843050914, 0.8274299246329025, 0.8782039894967157, 0.8789655057997423, 0.8814187025400727, 0.8895399418094561, 0.893822194687447, 0.8857148221793137, 0.8890075283507352, 0.89176834816078, 0.8884378186283766, 0.8911189631711546, 0.8928142579902733, 0.8934066854608267, 0.8968623041649023, 0.8931510014612659, 0.8925716516146236, 0.9001746031986286, 0.8991798619119055, 0.8934422519155063, 0.8989344387338195, 0.8986916264297081, 0.8767012800999159, 0.882335337360826, 0.8825297853881252, 0.8866933382543511, 0.8913201077163053, 0.8901312914224119, 0.8836937081745574, 0.8853480499257762, 0.8910888309686275, 0.886796855233206, 0.8860795653952355, 0.8908858706302281, 0.893273496997683, 0.891875295137013, 0.8915282413406754, 0.8876954767946144, 0.8949369391813679, 0.6380392509900442, 0.8906914102435921, 0.8871576534211725, 0.894124598319469, 0.9051557049927944, 0.9065179814716274, 0.8941512186292208, 0.8978232548112782, 0.9058522589018985, 0.9089290274202352, 0.9005742395496025, 0.8998697146637105, 0.8981642818437013, 0.9050690953163832, 0.9032750467037334, 0.9019389953886258, 0.9067860000571255, 0.9101528002592366, 0.9007772335414408, 0.9104279178632824, 0.9075457375213682, 0.8870941543956821, 0.9064685234396108, 0.9071090015880726],
"FL Recall":  [0.466269617315253, 0.4952565027074958, 0.5238767641381228, 0.5521392683319083, 0.5758299866696196, 0.6016931315292227, 0.6251210347719912, 0.6471558635296628, 0.6692699514516219, 0.6887718260263301, 0.7092332779148878, 0.724536308541916, 0.7436771329618831, 0.7630737743940547, 0.7798889117541282, 0.7993544976130361, 0.8141906792350175, 0.8292239016853051, 0.8431221958924283, 0.8568992749233304
083093875339, 0.9589609918146763, 0.9591726047695177, 0.9593458863517131, 0.9592323843146208, 0.958718193943499, 0.9589325772838725, 0.9592705417244325, 0.9591806463944698, 0.9590015302100001, 0.9593314979638305, 0.9589793183744926, 0.9607077485355289, 0.959488809492988, 0.9619957332216776, 0.9606058642803527, 0.9605279828910088, 0.9615587113806182, 0.9614059224075573, 0.9620631074079959, 0.9603589469227003, 0.9617454543516635, 0.9597031794509668, 0.9609439616888189, 0.9605920309296163, 0.960922907661752, 0.961147204256563, 0.9612439157375208, 0.9612191303618957, 0.9618844710860881, 0.9605997624918402, 0.961202303949358, 0.9626067865957687, 0.9631053401981386, 0.9631647938062985, 0.962573167949573, 0.9627856803225384, 0.9624638664513187, 0.9622624746227496, 0.9623096406094813, 0.9622328989307036, 0.9627784483287092, 0.9622747712508956, 0.9621276690935547, 0.9616951115696679, 0.9629377985554145, 0.9630703094299007, 0.963290938943041, 0.9634223890831951, 0.9622041617402626, 0.9633001723600649, 0.9637428027916645, 0.962860544200764, 0.9641900909258704, 0.9633603341015909, 0.9638860623818666, 0.9647415616786539, 0.96379398139865, 0.9640993678773484, 0.9645925372674666, 0.9642010175437342, 0.9643137692947068, 0.9649707568652456, 0.9655639527246741, 0.9661705020020307, 0.9665046322381501, 0.9662929288634491, 0.9648469942464988, 0.9661157558885473, 0.9660483951530686, 0.966106135304449, 0.9650314818245975, 0.9647332475683298, 0.966131372234261]
}

# Training rounds
n = 5

# Create a list of all rounds
all_rounds = np.arange(1, 101)

# Select specific rounds: 1, n, 2n, 3n, ..., 100
rounds = np.append(all_rounds[0], all_rounds[n-1::n])

# Update values to match new rounds
fl_metrics = {key: np.append(values[0], values[n-1::n]) for key, values in fl_metrics.items()}
cl_metrics = {key: np.append(values[0], values[n-1::n]) for key, values in cl_metrics.items()}

plot_validation_accuracies(rounds, fl_metrics, cl_metrics, 'mpm-non-iid-all.png')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Set the font family and size
plt.rcParams['font.family'] = 'CMU Serif'
plt.rcParams['font.size'] = 12

# Set the Seaborn color palette
sns.set_palette('tab10')

# non-IID FL results
fl_precision_noniid = np.array([0.4659516244508577, 0.4956165873124886, 0.5246002674202952, 0.5521467534949259, 0.5761168674677233, 0.6025247935425593, 0.6209151198741222, 0.6455194968176164, 0.6648237947565402, 0.687201018744369, 0.7090233903117822, 0.7274605735439817, 0.7468985807685442, 0.7646439246855713, 0.7803874307518461, 0.7948346951966834, 0.8083071478298025, 0.8247893732594674, 0.8399240488209697, 0.8585116995108966, 0.8699488013464215, 0.8848542411666797, 0.8687941728757999, 0.8600928408970171, 0.8697633312947097, 0.868768616834654, 0.8653300167967445, 0.8704126236096524, 0.8720028205134915, 0.8690165574609993, 0.86959306532817, 0.8663752964014729, 0.8669027895436817, 0.8646901723763849, 0.8685476494695994, 0.8630775718316865, 0.8751595116456923, 0.8708653843050914, 0.8274299246329025, 0.8782039894967157, 0.8789655057997423, 0.8814187025400727, 0.8895399418094561, 0.893822194687447, 0.8857148221793137, 0.8890075283507352, 0.89176834816078, 0.8884378186283766, 0.8911189631711546, 0.8
016313800792, 0.8931080687300325, 0.8920825302617698, 0.8981952826034083, 0.8986131465261963, 0.8950280772430073, 0.8990673822284814, 0.894779943160495, 0.8779262312387954, 0.883341154396267, 0.8810206708948188, 0.8863100267689079, 0.8902821334508562, 0.8902450678161131, 0.8849678243949639, 0.8856956175143503, 0.8936817368609763, 0.8860465922042323, 0.8887106916343619, 0.8903699972255639, 0.8921020211602012, 0.892503535944524, 0.8920355379652212, 0.8882051962766226, 0.8973013135954537, 0.6375612306968588, 0.8932607840068618, 0.8897714577023206, 0.8956440711066165, 0.9058809931899239, 0.9042846665980491, 0.8916291098224424, 0.898199590678003, 0.9051867707816844, 0.9081321399111133, 0.9002814710679773, 0.9012599784584365, 0.8985504477644224, 0.9077676525500403, 0.9043740717532737, 0.9016085569714013, 0.9056636748378707, 0.908399813009124, 0.9001717569676454, 0.9077949762632038, 0.9085789850393103, 0.8902003857329763, 0.9031173159512328, 0.9083061745213143])

# CL results
cl_results = np.array([0.966378499534982, 0.9660855749427466, 0.9625952649777715, 0.966131372234261])

metrics = ["Precision", "Recall", "Accuracy", "F1"]

def plot_graph(fl_precision, fl_recall, fl_accuracy, fl_f1, plot_name):
    fl_min = [fl_precision.min(), fl_recall.min(), fl_accuracy.min(), fl_f1.min()]
    fl_max = [fl_precision.max(), fl_recall.max(), fl_accuracy.max(), fl_f1.max()]
    fl_final = [fl_precision[-1], fl_recall[-1], fl_accuracy[-1], fl_f1[-1]]

    x = np.arange(len(metrics))

    fig, ax = plt.subplots(figsize=(8, 5.6))

    bar_width = 0.20
    opacity = 0.8
    hatch_patterns = ['//', '\\\\', '++', 'xx']

    rects1 = ax.bar(x - bar_width, fl_min, bar_width, alpha=opacity, label='FL Min', hatch=hatch_patterns[0])
    rects2 = ax.bar(x, fl_max, bar_width, alpha=opacity, label='FL Max', hatch=hatch_patterns[1])
    rects3 = ax.bar(x + bar_width, fl_final, bar_width, alpha=opacity, label='FL Final', hatch=hatch_patterns[2])
    rects4 = ax.bar(x + 2*bar_width, cl_results, bar_width, alpha=opacity, label='CL Result', hatch=hatch_patterns[3])

    # Adding labels
    ax.set_xlabel('Metrics', labelpad=20)
    ax.set_ylabel('Values', labelpad=20)
    ax.set_xticks(x)
    ax.set_xticklabels(metrics)
    ax.set_ylim(0, 1.1)  # Increase y-axis limit

    # Set the legend
    ax.legend(loc='lower left', bbox_to_anchor=(0., 1.02, 1., .102), fancybox=True, shadow=True, ncol=2, mode="expand", borderaxespad=0.)

    ax.grid(axis='y', linestyle='--', alpha=0.6)

    # Function to attach a label above each bar in rects
    def autolabel(rects):
        for rect in rects:
            height = rect.get_height()
            ax.annotate('{:.2f}'.format(height),
                        xy=(rect.get_x() + rect.get_width() / 2, height),
                        xytext=(0, 3),  # Offset label by 3 points above bar
                        textcoords="offset points",
                        ha='center', va='bottom')

    autolabel(rects1)
    autolabel(rects2)
    autolabel(rects3)
    autolabel(rects4)

    fig.tight_layout()
    plt.savefig(plot_name, dpi=300, bbox_inches='tight')
    plt.show()
    plt.close()

plot_graph(fl_precision_noniid, fl_recall_noniid, fl_accuracy_noniid, fl_f1_noniid, 'mpm-non-iid.png')

# %% [markdown]
# ## Plot the normalized confusion matrices

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Define the labels for our axes
labels = ["QUIC.YouTube", "TLS.TikTok", "TLS.Apple", "Discord", "BitTorrent",
         "QUIC.Facebook", "STUN", "HTTP", "SSH", "WhatsApp"]


# Define the confusion matrix
fl_noniid_confusion = np.array([
            [8.940e-01, 1.000e-04, 4.000e-04, 1.070e-02, 7.950e-02, 1.460e-02, 3.000e-04, 5.000e-04, 0.000e+00, 0.000e+00],
            [9.400e-03, 8.987e-01, 3.390e-02, 3.000e-03, 2.900e-03, 8.000e-03, 1.600e-03, 2.090e-02, 1.460e-02, 6.800e-03],
            [0.000e+00, 7.200e-03, 8.825e-01, 0.000e+00, 0.000e+00, 0.000e+00, 1.000e-04, 8.360e-02, 2.660e-02, 1.000e-04],
            [6.000e-04, 3.000e-04, 3.200e-03, 9.532e-01, 2.060e-02, 1.600e-03, 1.700e-02, 3.500e-03, 0.000e+00, 0.000e+00],
            [1.600e-03, 3.000e-04, 4.000e-04, 9.300e-03, 8.498e-01, 9.080e-02, 1.120e-02, 3.660e-02, 0.000e+00, 0.000e+00],
            [1.740e-02, 0.000e+00, 1.000e-04, 3.000e-03, 1.560e-01, 8.082e-01, 1.530e-02, 1.000e-04, 0.000e+00, 0.000e+00],
            [3.000e-04, 0.000e+00, 0.000e+00, 1.700e-03, 6.030e-02, 1.600e-03, 9.362e-01, 0.000e+00, 0.000e+00, 0.000e+00],
            [0.000e+00, 6.700e-03, 1.900e-03, 1.144e-01, 2.200e-03, 0.000e+00, 2.250e-02, 8.521e-01, 1.000e-04, 2.000e-04],
            [0.000e+00, 8.900e-03, 6.000e-04, 0.000e+00, 1.200e-03, 0.000e+00, 1.173e-01, 0.000e+00, 8.719e-01, 0.000e+00],
            [0.000e+00, 3.000e-04, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 9.850e-02, 9.012e-01]
        ])

FSIZE = 14

# Set the font family and size
plt.rcParams['font.family'] = 'CMU Serif'
plt.rcParams['font.size'] = FSIZE

cmap = sns.color_palette("Blues", as_cmap=True)

# Function to plot a confusion matrix
def plot_confusion_matrix(confusion_matrix, plot_name):
    fig, ax = plt.subplots(figsize=(12, 10))

    heatmap = sns.heatmap(confusion_matrix
                          , annot=True
                          , fmt=".4f"
                          , linewidths=.5
                          , ax=ax
                          , cmap=cmap
                          , cbar=True
                          , rasterized=False
                          )
    
    cbar = heatmap.collections[0].colorbar
    cbar.ax.tick_params(labelsize=FSIZE)

    for spine in ax.spines.values():
        spine.set(visible=True, lw=.8, edgecolor="black")

    # Set up axes
    ax.set_xticklabels(labels, rotation=45, ha='center', fontsize=FSIZE)  # Rotate the x-axis tick labels by 45 degrees
    ax.set_yticklabels(labels, rotation=45, ha='right', fontsize=FSIZE)  # Rotate the y-axis tick labels by 45 degrees
    ax.set_xlabel('Predictions', fontsize=FSIZE)
    ax.set_ylabel('Actuals', fontsize=FSIZE)

        
    # Move the x-axis tick labels to the top
#     ax.xaxis.set_tick_params(labeltop=True, labelbottom=False)
    ax.xaxis.set_tick_params(labeltop=False, labelbottom=False)

    # Move the x-axis ticks to the top
#     ax.tick_params(axis='x', which='both', top=True, bottom=False)
    ax.tick_params(axis='x', which='both', top=False, bottom=False)
    
    # Show the plot
    plt.savefig(plot_name, dpi=300, bbox_inches='tight')
    plt.show()

plot_confusion_matrix(fl_noniid_confusion, "cm-non-iid.png")
