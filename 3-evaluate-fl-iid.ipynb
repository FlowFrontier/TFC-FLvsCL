# %% [markdown]
# # IID Results

# %% [markdown]
# ## Plot client, global, and centralised model validation accuracies

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from matplotlib.lines import Line2D

def plot_validation_accuracies(rounds,client_accuracies, aggregated_accuracies, cl_accuracies, filename):
    # Replace zeros with np.nan
    for key, values in client_accuracies.items():
        client_accuracies[key] = [value if value != 0.0 else np.nan for value in values]

    # Initialize list for lines and labels
    lines = []
    labels = []

    # Create a line plot for each client
    markers = ['o', '^', 's', 'p', '*']
    for i, (client, accuracies) in enumerate(client_accuracies.items()):
        line, = plt.plot(rounds
                         , accuracies
                         , marker=markers[i]
                         , color=color_palette[i]
                         , linestyle = ":"
#                          , markersize=6
#                          , markeredgewidth=2
                         , markerfacecolor='white'
#                          , markeredgecolor=color_palette[i]
                         , alpha=0.8
                         , linewidth=1)
        lines.append(line)
        labels.append(f'Client {client}')

    # Add an empty label
    lines.append(Line2D([0], [0], marker=None, linestyle=None, color='none'))
    labels.append("")

    # Create a line plot for the aggregated model
    fl_model, = plt.plot(rounds
                         , aggregated_accuracies
                         , marker='x'
                         , linestyle='-'
                         , linewidth=1
                         , color=color_palette[i+1]
#                          , markersize=6
#                          , markeredgewidth=2
                         , markerfacecolor='white'
#                          , markeredgecolor=color_palette[i+1]
                         , alpha=1)
    lines.append(fl_model)
    labels.append('FL Model')

    # Create a line plot for the centralised model
    cl_model, = plt.plot(rounds
                         , cl_accuracies
                         , marker='x'
                         , linestyle='-'
                         , linewidth=1
                         , color=color_palette[i+2]
#                          , markersize=6
#                          , markeredgewidth=2
                         , markerfacecolor='white'
#                          , markeredgecolor=color_palette[i+2]
                         , alpha=1)
    lines.append(cl_model)
    labels.append('CL Model')

    # Add title and labels
    plt.xlabel('Epochs')
    plt.ylabel('Validation Accuracy')

    # Add a legend
    plt.legend(lines, labels,
               bbox_to_anchor=(0., 1.02, 1., .102),
               loc='lower left',
               ncol=4,
               mode="expand",
               borderaxespad=0.,
               fancybox=True,
               shadow=True)

    plt.grid(linestyle='--', linewidth=0.5)

    # Set x ticks
    plt.xticks(rounds)

    # Show the plot
    plt.tight_layout()

    # Save the plot
    plt.savefig(filename, dpi=300, bbox_inches='tight')
    
    plt.show()

    # Clear the current plot to make ready for the next plot
    plt.clf()

# Set the font and color palette
sns.set_theme(style="whitegrid")
plt.rcParams['font.family'] = 'CMU Serif'
plt.rcParams['font.size'] = '14'
color_palette = sns.color_palette("bright")

# Centralised model data
cl_accuracies = [0.9210447392562275, 0.9317841013337097, 0.9368163855761767, 0.9398154682097241, 0.941681074024416, 0.9424440759297156, 0.9451211982217204, 0.9466913061886952, 0.9483584432996965, 0.9481423329334556, 0.9499373720979465, 0.949716851316068, 0.9488744619292923, 0.9500299908263354, 0.9504533907275422, 0.9502284595300261, 0.9514589654929081, 0.9510223343447887, 0.9520587820196176, 0.9530423047067955, 0.9531525650977348, 0.9532495942417614, 0.9534921671018277, 0.9530511255380707, 0.9544007127231671, 0.9548152917930985, 0.9555518312045728, 0.9553489520852445, 0.9557811728177263, 0.9560237456777927, 0.9561781102251076, 0.9559311269494037, 0.956111953990544, 0.9564118622538988, 0.9563765789287982, 0.9562266247971208, 0.956266318537859, 0.9565706372168513, 0.957558570319667, 0.9569411121304072, 0.9584053701220803, 0.9572542516406746, 0.957404205772352, 0.95822454308094, 0.9581804389245643, 0.9585068096817444, 0.9576114953073178, 0.9583700867969798, 0.9572718933032249, 0.9582333639122151, 0.9579025827393973, 0.9580613577023499, 0.9583083409780537, 0.958480347187919, 0.9584230117846306, 0.9590713428833533, 0.9583215722249665, 0.9587140992167101, 0.9600151718297932, 0.9601077905581822, 0.9601122009738198, 0.9600901488956319, 0.9600989697269071, 0.9599622468421424, 0.9597858302166397, 0.9598343447886529, 0.9600504551548938, 0.9603812363277116, 0.9600107614141556, 0.9600151718297932, 0.9596711594100628, 0.9602489238585844, 0.9604385717309999, 0.9606502716816033, 0.9605620633688519, 0.9600372239079811, 0.9604606238091877, 0.960826688307106, 0.9602930280149601, 0.9611177757391857, 0.9606193987721403, 0.960950179944958, 0.9617043610189824, 0.9612192152988498, 0.961483840237104, 0.9618499047350222, 0.9612721402865007, 0.9616823089407945, 0.9620527838543504, 0.962312998376967, 0.9627981440970997, 0.9629348669818644, 0.9630230752946157, 0.9620351421918002, 0.9628554795003881, 0.9628378378378378, 0.9625423399901206, 0.9622512525580411, 0.9618322630724719, 0.9625952649777715]

# Client Data
client_accuracies = {
    "1": [0.8056, 0.8167, 0.8612, 0.8701, 0.8639, 0.8728, 0.8754, 0.8835, 0.8763, 0.8879, 0.8835, 0.8915, 0.8861, 0.8959, 0.895, 0.8986, 0.8968, 0.8995, 0.8968, 0.8995, 0.8906, 0.8977, 0.9021, 0.9012, 0.9039, 0.9012, 0.9012, 0.9039, 0.9039, 0.9075, 0.9093, 0.9048, 0.9004, 0.9075, 0.9084, 0.911, 0.9066, 0.9075, 0.9181, 0.9071, 0.9142, 0.9142, 0.916, 0.9106, 0.9133, 0.9097, 0.9276, 0.9196, 0.9088, 0.9142, 0.908, 0.9169, 0.9142, 0.9223, 0.9258, 0.9106, 0.9231, 0.9115, 0.9142, 0.9196, 0.9303, 0.9258, 0.9115, 0.9267, 0.9205, 0.9205, 0.9294, 0.9205, 0.9258, 0.9187, 0.9223, 0.9223, 0.9223, 0.916, 0.9142, 0.9321, 0.9365, 0.9264, 0.9228, 0.9361, 0.9343, 0.9281, 0.9326, 0.9201, 0.9281, 0.9308, 0.9281, 0.9414, 0.9397, 0.9308, 0.9299, 0.937, 0.9423, 0.9379, 0.9299, 0.9281, 0.9406, 0.9406, 0.9343, 0.9317],
    "2": [0.7929, 0.8096, 0.839, 0.8452, 0.8541, 0.8594, 0.8639, 0.8719, 0.8577, 0.8808, 0.8826, 0.8835, 0.8879, 0.8843, 0.8808, 0.8852, 0.8897, 0.8861, 0.895, 0.8932, 0.9048, 0.8986, 0.8968, 0.9057, 0.9021, 0.9012, 0.9119, 0.8995, 0.895, 0.9075, 0.903, 0.9084, 0.9039, 0.9101, 0.9057, 0.9057, 0.9048, 0.8986, 0.8979, 0.8978, 0.9058, 0.9076, 0.9067, 0.9076, 0.9093, 0.9129, 0.9084, 0.9102, 0.9084, 0.9049, 0.904, 0.92, 0.9022, 0.9093, 0.9173, 0.9058, 0.9102, 0.9191, 0.9067, 0.9093, 0.9049, 0.9022, 0.9076, 0.904, 0.9156, 0.92, 0.9102, 0.9227, 0.9084, 0.9191, 0.9058, 0.8987, 0.9173, 0.9164, 0.9191, 0.928, 0.9046, 0.9217, 0.9164, 0.9413, 0.9537, 0.9511, 0.9217, 0.9422, 0.9546, 0.9484, 0.9217, 0.9511, 0.9626, 0.9591, 0.9395, 0.9448, 0.9537, 0.9626, 0.9493, 0.9591, 0.9546, 0.9609, 0.9484, 0.9609],
    "3": [0.8029, 0.8468, 0.8539, 0.8556, 0.8671, 0.8804, 0.876, 0.8778, 0.876, 0.8822, 0.8804, 0.8663, 0.868, 0.884, 0.8866, 0.8955, 0.899, 0.8964, 0.8911, 0.8866, 0.9017, 0.9052, 0.9026, 0.9026, 0.9026, 0.9097, 0.9105, 0.9097, 0.9097, 0.9132, 0.9141, 0.9176, 0.9105, 0.9105, 0.9167, 0.9194, 0.9167, 0.9159, 0.913, 0.9023, 0.921, 0.9103, 0.9147, 0.9174, 0.9041, 0.9067, 0.9041, 0.9201, 0.9174, 0.9112, 0.9112, 0.9085, 0.9147, 0.9067, 0.9076, 0.9085, 0.9085, 0.9121, 0.913, 0.913, 0.9139, 0.9156, 0.9147, 0.9156, 0.9085, 0.921, 0.9245, 0.9156, 0.9183, 0.9272, 0.9254, 0.9281, 0.9281, 0.9201, 0.9139, 0.9245, 0.9199, 0.9297, 0.9297, 0.9199, 0.927, 0.9226, 0.9395, 0.9351, 0.9306, 0.9279, 0.9342, 0.9279, 0.9226, 0.9306, 0.9377, 0.9351, 0.9359, 0.9279, 0.9244, 0.9377, 0.9359, 0.9253, 0.9342, 0.9288],
    "4": [0.8139, 0.8242, 0.8561, 0.8544, 0.8668, 0.8694, 0.8615, 0.8757, 0.8757, 0.8872, 0.889, 0.8908, 0.8872, 0.8854, 0.8872, 0.8952, 0.8925, 0.8872, 0.9005, 0.8961, 0.8996, 0.8952, 0.9023, 0.9041, 0.9032, 0.9023, 0.9112, 0.8908, 0.9103, 0.913, 0.913, 0.9085, 0.9139, 0.9085, 0.9041, 0.9094, 0.9121, 0.9165, 0.9037, 0.8961, 0.897, 0.8996, 0.9041, 0.9032, 0.9067, 0.8996, 0.905, 0.9023, 0.9076, 0.9067, 0.8988, 0.9139, 0.9014, 0.9094, 0.9121, 0.8996, 0.9103, 0.913, 0.913, 0.9103, 0.9085, 0.9085, 0.9156, 0.9103, 0.9103, 0.9076, 0.9085, 0.9139, 0.9112, 0.9139, 0.9121, 0.9103, 0.9174, 0.9174, 0.913, 0.9103, 0.9249, 0.9315, 0.9324, 0.9279, 0.9279, 0.9279, 0.9377, 0.9315, 0.9297, 0.9306, 0.9315, 0.9342, 0.9404, 0.9368, 0.9315, 0.9279, 0.9333, 0.9368, 0.9315, 0.9324, 0.9297, 0.9351, 0.9288, 0.9315],
    "5": [0.8131, 0.7957, 0.8393, 0.8428, 0.8455, 0.8481, 0.8499, 0.8579, 0.8632, 0.8783, 0.8668, 0.8659, 0.8774, 0.865, 0.8757, 0.8748, 0.8837, 0.889, 0.8837, 0.889, 0.8925, 0.8872, 0.8925, 0.8925, 0.8899, 0.8908, 0.897, 0.8917, 0.8979, 0.8943, 0.8952, 0.9085, 0.9023, 0.9032, 0.8996, 0.9103, 0.8979, 0.9023, 0.908, 0.8925, 0.9085, 0.9174, 0.905, 0.8996, 0.8979, 0.9041, 0.9014, 0.8979, 0.9076, 0.9023, 0.9076, 0.9218, 0.9156, 0.9121, 0.9174, 0.9059, 0.9272, 0.9183, 0.9192, 0.9227, 0.9139, 0.9165, 0.9192, 0.9112, 0.9059, 0.9112, 0.9192, 0.9218, 0.9147, 0.9103, 0.9201, 0.9139, 0.9281, 0.9103, 0.9147, 0.9227, 0.9349, 0.9164, 0.9173, 0.9155, 0.9217, 0.919, 0.9146, 0.9199, 0.9226, 0.9208, 0.9253, 0.9235, 0.9244, 0.9244, 0.9137, 0.9262, 0.9235, 0.9262, 0.9235, 0.9351, 0.9226, 0.9288, 0.9235, 0.9279]
}

# Server Data
aggregated_accuracies = [0.8056067362662552, 0.8182520108894085, 0.8498025329320529, 0.8535119694318641, 0.8593967207023724, 0.8658739606057677, 0.8652309453571633, 0.873274781531313, 0.8697094073325201, 0.8832644200718002, 0.880397412377994, 0.8794524597774738, 0.8812529179977724, 0.8828060704966424, 0.8850122264503493, 0.8897727729367494, 0.8923072300604845, 0.8916082701424768, 0.8933831723388199, 0.8928556360850668, 0.8978071387183167, 0.8967421648096351, 0.8992421018808089, 0.901196272276938, 0.9003090714076101, 0.9009996082184258, 0.9063189210956079, 0.8990624162838805, 0.9033182602973451, 0.9070475167895137, 0.90686528908533, 0.9095401118845597, 0.9061709501629464, 0.9079524485018127, 0.9068646527860952, 0.9111377980971315, 0.9075745820553655, 0.9081036943726111, 0.9080854956453, 0.8991314739190374, 0.9092284484420368, 0.9097789212269641, 0.909272264726325, 0.9076385719630264, 0.9062304728278073, 0.9065769139102713, 0.9092037109942075, 0.9099320254947405, 0.909944646188382, 0.9078396728223239, 0.9059002104429096, 0.9161957399686335, 0.9095747624796845, 0.9119277117864006, 0.9159995729108386, 0.9060648639548425, 0.9157951529814836, 0.914788610942184, 0.9132026113038287, 0.914949673619345, 0.9142179664781036, 0.9136506045047166, 0.9137031493625484, 0.913498054570523, 0.9121299428478438, 0.9160260880502594, 0.9182894350006299, 0.9188866395131404, 0.9156400984198774, 0.9178047092480334, 0.9170836159681258, 0.9145474413513813, 0.9226149239205355, 0.9160287464316208, 0.9149750420314285, 0.9234611309284337, 0.9240141745106556, 0.9251072613844541, 0.9236752843042344, 0.9280399986965333, 0.9327887469343837, 0.929606614214487, 0.9291207148420113, 0.9296789878651396, 0.9329900488687973, 0.9316118432883718, 0.9281389709337774, 0.9355174333958036, 0.9377210798559505, 0.9361874379052987, 0.930369646495381, 0.9341519961589744, 0.9376333182050041, 0.9381019128171136, 0.9316279477834126, 0.9383576319529837, 0.9365558828143594, 0.9379745269434691, 0.933766603000873, 0.9359973309242589]

# Training rounds
n = 5

# Create a list of all rounds
all_rounds = np.arange(1, 101)

# Select specific rounds: 1, n, 2n, 3n, ..., 100
rounds = np.append(all_rounds[0], all_rounds[n-1::n])

# Update values to match new rounds
cl_accuracies = np.append(cl_accuracies[0], cl_accuracies[n-1::n])
client_accuracies = {key: np.append(values[0], values[n-1::n]) for key, values in client_accuracies.items()}
aggregated_accuracies = np.append(aggregated_accuracies[0], aggregated_accuracies[n-1::n])

plot_validation_accuracies(rounds, client_accuracies, aggregated_accuracies, cl_accuracies, 'val-acc-iid-all.png')

# %% [markdown]
# ## Plot client, global, and centralised model validation losses

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from matplotlib.lines import Line2D

def plot_validation_losses(rounds, client_losses, aggregated_losses, cl_losses, filename):
    # Replace zeros with np.nan
    for key, values in client_losses.items():
        client_losses[key] = [value if value != 0.0 else np.nan for value in values]

    # Initialize list for lines and labels
    lines = []
    labels = []

    # Create a line plot for each client
    markers = ['o', '^', 's', 'p', '*']
    for i, (client, losses) in enumerate(client_losses.items()):
        line, = plt.plot(rounds
                         , losses
                         , marker=markers[i]
                         , color=color_palette[i]
                         , linestyle=':'
#                          , markersize=6
#                          , markeredgewidth=2
                         , markerfacecolor='white'
#                          , markeredgecolor=color_palette[i]
#                          , zorder=len(client_losses)-i  # setting zorder                         
                         , alpha=0.8
                         , linewidth=1)
        lines.append(line)
        labels.append(f'Client {client}')

    # Add an empty label
    lines.append(Line2D([0], [0], marker=None, linestyle=None, color='none'))
    labels.append("")

    # Create a line plot for the aggregated model
    fl_model, = plt.plot(rounds
                         , aggregated_losses
                         , marker='x'
                         , linestyle='-'
                         , linewidth=1
                         , color=color_palette[i+1]
#                          , markersize=6
#                          , markeredgewidth=2
                         , markerfacecolor='white'
#                          , markeredgecolor=color_palette[i+1]
                         , alpha=1)
    lines.append(fl_model)
    labels.append('FL Model')

    # Create a line plot for the centralised model
    cl_model, = plt.plot(rounds
                         , cl_losses
                         , marker='x'
                         , linestyle='-'
                         , linewidth=1
                         , color=color_palette[i+2]
#                          , markersize=6
#                          , markeredgewidth=2
                         , markerfacecolor='white'
#                          , markeredgecolor=color_palette[i+2]
                         , alpha=1)
    lines.append(cl_model)
    labels.append('CL Model')

    # Add title and labels
    plt.xlabel('Epochs')
    plt.ylabel('Validation Loss')

    # Add a legend
    plt.legend(lines, labels,
               bbox_to_anchor=(0., 1.02, 1., .102),
               loc='lower left',
               ncol=4,
               mode="expand",
               borderaxespad=0.,
               fancybox=True,
               shadow=True)

    plt.grid(linestyle='--', linewidth=0.5)

    # Set x ticks
    plt.xticks(rounds)

    # Show the plot
    plt.tight_layout()

    # Save the plot
    plt.savefig(filename, dpi=300, bbox_inches='tight')
    
    plt.show()

    # Clear the current plot to make ready for the next plot
    plt.clf()

# Set the font and color palette
sns.set_theme(style="whitegrid")
plt.rcParams['font.family'] = 'CMU Serif'
plt.rcParams['font.size'] = '14'
color_palette = sns.color_palette("bright")

cl_losses = [0.21439142521647178, 0.1824418762577187, 0.16677634160433083, 0.16112545886343876, 0.15476418980088727, 0.154554029553432, 0.14886774239506567, 0.14745121731829453, 0.1433074463649251, 0.14362230445766666, 0.1390900456442326, 0.13716919577264058, 0.13822223889828045, 0.1357727873487204, 0.13511253414602906, 0.1368475320393635, 0.13374907465894928, 0.13241828522810487, 0.13096857350575933, 0.13007704916974488, 0.12920513580852327, 0.12989815599295254, 0.12925607853006327, 0.13228924278763718, 0.12781758718243838, 0.12833201396671715, 0.12536647564203607, 0.12554817650566788, 0.12540268867075702, 0.1251183883484502, 0.12483240673015535, 0.12596926948467824, 0.12561233020650142, 0.12503745299235916, 0.12675796722794516, 0.12478236989151348, 0.12625815006688412, 0.12515597911740212, 0.12121254060892309, 0.12343636691291233, 0.1198145353682071, 0.12279661728074312, 0.12220445413628248, 0.12103732016116195, 0.12166080013921463, 0.1204377572257491, 0.12222243881852136, 0.11988996355408921, 0.12224981796503, 0.12064494115385453, 0.12130928741364874, 0.12097658901496072, 0.11904669459541167, 0.11941964068328385, 0.11884077410042448, 0.11727073316130253, 0.11910332217300577, 0.11886630982901762, 0.11616618307049081, 0.11571297196124705, 0.11467756746053169, 0.11636425098903105, 0.11485907347430818, 0.11615938358969036, 0.11620848381868976, 0.11727292447121358, 0.11674190409824323, 0.11532268062892836, 0.11740962510850173, 0.11739737574244, 0.11666146220398681, 0.11466670028813944, 0.11461518582671136, 0.11400543740980033, 0.11392913732315448, 0.1161406201623416, 0.1138536328260308, 0.11668255709609325, 0.11429651311468132, 0.11271753846432099, 0.11408342022668153, 0.11327657604534327, 0.11194777089418154, 0.11286678138935535, 0.11254405177454463, 0.1121698888891493, 0.11635559167975545, 0.11236111988891768, 0.11151132381210112, 0.11005239173420713, 0.10958144867499087, 0.1089325990535689, 0.11014562663076394, 0.11217783079573637, 0.1094911392930235, 0.10905413510851343, 0.10911129482536583, 0.10938399274881543, 0.11113561229762177, 0.10944428849583104]

client_losses = {
    "1": [0.486975, 0.39817500000000006, 0.355275, 0.3183, 0.3027, 0.288525, 0.27465, 0.262725, 0.27825, 0.262725, 0.24825000000000003, 0.2415, 0.242925, 0.24022499999999997, 0.231225, 0.229125, 0.22590000000000002, 0.22649999999999998, 0.225375, 0.226725, 0.22590000000000002, 0.21982500000000002, 0.209475, 0.21405, 0.20325000000000001, 0.21787499999999999, 0.206175, 0.19867500000000002, 0.20700000000000002, 0.188625, 0.19627499999999998, 0.187425, 0.194025, 0.18030000000000002, 0.18795, 0.17745, 0.184275, 0.17025, 0.169425, 0.1845, 0.177825, 0.18495, 0.18465, 0.18555, 0.17550000000000002, 0.18022500000000002, 0.176925, 0.16965000000000002, 0.1797, 0.17662499999999998, 0.17122500000000002, 0.16447499999999998, 0.1665, 0.167775, 0.16635, 0.1635, 0.1635, 0.16567500000000002, 0.1626, 0.166575, 0.156225, 0.153525, 0.1779, 0.1686, 0.15262499999999998, 0.1638, 0.15765, 0.1506, 0.154725, 0.156525, 0.152475, 0.15360000000000001, 0.144975, 0.15262499999999998, 0.15465, 0.14700000000000002, 0.191625, 0.14429999999999998, 0.159825, 0.147675, 0.144075, 0.14939999999999998, 0.15315, 0.17452499999999999, 0.141375, 0.13605, 0.15757500000000002, 0.142275, 0.14182499999999998, 0.145875, 0.13942500000000002, 0.13905, 0.14265, 0.14789999999999998, 0.141225, 0.16035, 0.1368, 0.14250000000000002, 0.135825, 0.140025],
    "2": [0.507375, 0.41069999999999995, 0.35309999999999997, 0.3261, 0.2973, 0.28507499999999997, 0.282225, 0.278625, 0.294075, 0.25012500000000004, 0.26265, 0.23917500000000003, 0.250875, 0.23025, 0.23452499999999998, 0.23310000000000003, 0.22860000000000003, 0.22852500000000003, 0.229125, 0.21585, 0.21532500000000002, 0.204975, 0.215475, 0.201675, 0.197325, 0.196125, 0.201825, 0.18795, 0.19717500000000002, 0.185025, 0.18989999999999999, 0.18525, 0.20025, 0.18157500000000001, 0.180675, 0.181875, 0.18157500000000001, 0.1935, 0.18839999999999998, 0.186975, 0.188475, 0.18045, 0.178875, 0.18075, 0.179775, 0.17685, 0.175125, 0.185775, 0.1701, 0.18045, 0.1743, 0.176775, 0.17985, 0.1785, 0.15795, 0.177525, 0.164025, 0.16754999999999998, 0.1866, 0.166575, 0.18810000000000002, 0.16342500000000001, 0.1614, 0.16935, 0.161025, 0.156825, 0.1605, 0.160425, 0.15562499999999999, 0.157275, 0.1827, 0.172425, 0.15465, 0.150375, 0.149925, 0.144975, 0.23805, 0.172425, 0.17535, 0.142575, 0.12945, 0.1227, 0.16267500000000001, 0.13335000000000002, 0.114975, 0.11715, 0.158325, 0.12735000000000002, 0.1179, 0.10447500000000001, 0.135675, 0.11730000000000002, 0.11865, 0.1023, 0.1428, 0.12135, 0.100125, 0.09555000000000001, 0.1371, 0.1092],
    "3": [0.462075, 0.36945, 0.327975, 0.30157500000000004, 0.28755000000000003, 0.28042500000000004, 0.2631, 0.26527500000000004, 0.2568, 0.25934999999999997, 0.252375, 0.274875, 0.2718, 0.24795, 0.240525, 0.23325, 0.225825, 0.22755, 0.2328, 0.22635, 0.21187499999999998, 0.21787499999999999, 0.198825, 0.200475, 0.19605, 0.19372499999999998, 0.19447499999999998, 0.1941, 0.17872500000000002, 0.1773, 0.17415, 0.1683, 0.178275, 0.1707, 0.168825, 0.170625, 0.1629, 0.167625, 0.17880000000000001, 0.19319999999999998, 0.19177499999999997, 0.19627499999999998, 0.18345, 0.19035000000000002, 0.19005, 0.1851, 0.201825, 0.18434999999999999, 0.178425, 0.174675, 0.17880000000000001, 0.176175, 0.17295, 0.180675, 0.1749, 0.18382500000000002, 0.17250000000000001, 0.17400000000000002, 0.169875, 0.1677, 0.167625, 0.1689, 0.17385, 0.170325, 0.2031, 0.17625, 0.19035000000000002, 0.1698, 0.16785, 0.18525, 0.16365000000000002, 0.16635, 0.15975, 0.163725, 0.175875, 0.15795, 0.14354999999999998, 0.13642500000000002, 0.12862500000000002, 0.1446, 0.129825, 0.1305, 0.142725, 0.129075, 0.123975, 0.12525, 0.1266, 0.1242, 0.13065, 0.12614999999999998, 0.12525, 0.12675, 0.12464999999999998, 0.118275, 0.12712500000000002, 0.1314, 0.12862500000000002, 0.1284, 0.126, 0.14850000000000002],
    "4": [0.461025, 0.3801, 0.3366, 0.317625, 0.29557500000000003, 0.292125, 0.283275, 0.268125, 0.26655, 0.260625, 0.247125, 0.238425, 0.240975, 0.2364, 0.22785, 0.2268, 0.21975, 0.23677499999999999, 0.2169, 0.2121, 0.20145000000000002, 0.215475, 0.1992, 0.207675, 0.186825, 0.18930000000000002, 0.18885000000000002, 0.22755, 0.181275, 0.18735, 0.1728, 0.174075, 0.171675, 0.170925, 0.17504999999999998, 0.1674, 0.16567500000000002, 0.168975, 0.19965, 0.193425, 0.21112499999999998, 0.20504999999999998, 0.186975, 0.19177499999999997, 0.177375, 0.1941, 0.170025, 0.186225, 0.16845, 0.175125, 0.179775, 0.17535, 0.19875, 0.16754999999999998, 0.1686, 0.19522499999999998, 0.163875, 0.1638, 0.167175, 0.1764, 0.175125, 0.17415, 0.160875, 0.17662499999999998, 0.1617, 0.165525, 0.16297499999999998, 0.166575, 0.165225, 0.16417500000000002, 0.1605, 0.160875, 0.15007500000000001, 0.1557, 0.161325, 0.156675, 0.15007500000000001, 0.13695000000000002, 0.14032499999999998, 0.13695000000000002, 0.1401, 0.13942500000000002, 0.1308, 0.13672499999999999, 0.1341, 0.1314, 0.133275, 0.13065, 0.13185000000000002, 0.125925, 0.137625, 0.1557, 0.128325, 0.13005, 0.1305, 0.12945, 0.135675, 0.13124999999999998, 0.140025, 0.129225],
    "5": [0.47287499999999993, 0.4152, 0.36765000000000003, 0.329025, 0.3177, 0.3027, 0.287775, 0.283275, 0.2919, 0.27375, 0.25515, 0.26849999999999996, 0.258675, 0.291375, 0.24405000000000002, 0.2397, 0.26775, 0.23272500000000002, 0.22635, 0.239625, 0.21802500000000002, 0.21960000000000002, 0.2148, 0.22199999999999998, 0.2298, 0.232875, 0.21149999999999997, 0.20752500000000002, 0.20137500000000003, 0.21832500000000002, 0.20692499999999997, 0.192675, 0.191025, 0.188925, 0.187275, 0.182025, 0.189, 0.1875, 0.19222499999999998, 0.1989, 0.186825, 0.18045, 0.18405, 0.20227499999999998, 0.1785, 0.17685, 0.17745, 0.175575, 0.185325, 0.17654999999999998, 0.18712499999999999, 0.17235, 0.175275, 0.195525, 0.165075, 0.158025, 0.15435000000000001, 0.16492500000000002, 0.159, 0.16469999999999999, 0.1557, 0.156525, 0.149625, 0.1587, 0.168375, 0.15405, 0.14654999999999999, 0.14602500000000002, 0.1644, 0.1482, 0.150375, 0.16995, 0.154425, 0.17085, 0.15375, 0.1476, 0.13274999999999998, 0.14354999999999998, 0.1527, 0.16875, 0.1674, 0.143925, 0.15847499999999998, 0.1365, 0.13905, 0.138525, 0.138525, 0.14175, 0.13815, 0.137325, 0.153225, 0.13065, 0.13792500000000002, 0.152175, 0.143475, 0.1344, 0.141225, 0.130275, 0.13942500000000002, 0.129525]    
}

aggregated_losses = [0.4774465389322254, 0.3939360169976196, 0.34754427161902895, 0.31823198503177874, 0.2998370856828825, 0.28957704660521333, 0.2779293789293812, 0.2713743980019411, 0.27676395203226606, 0.2610972312733568, 0.2529890466213526, 0.251528933088952, 0.2525586149646606, 0.24751173415844593, 0.23548610909746867, 0.2323125125379585, 0.2323976084976365, 0.23035238950890896, 0.225984938988215, 0.223720074985399, 0.21421271387431423, 0.21540444868430453, 0.2072979545033914, 0.20887159397854987, 0.2016715897792009, 0.20468899467155438, 0.2002368764611522, 0.2022716850274968, 0.19245511971483822, 0.19037256930138077, 0.1871068139505309, 0.18109324214213401, 0.1864494428388162, 0.17821796136186363, 0.17965544426541283, 0.17567317005175503, 0.17605824371332637, 0.17693641246911793, 0.18508910508685164, 0.191263388036733, 0.1906008839136394, 0.18895004279201272, 0.1835614229977713, 0.18987167168831603, 0.18010034164685962, 0.18240115328023035, 0.17963651074798645, 0.1800683847270984, 0.1761758984843236, 0.1766618622157422, 0.1780824996591511, 0.17290232643788647, 0.1780311058902589, 0.17742949437646244, 0.16639409857851717, 0.1745835579251854, 0.1634471124031437, 0.16711355050468815, 0.16853820755550228, 0.168292300124182, 0.16769600101982307, 0.16295027515882837, 0.16410450960126438, 0.1685194405157629, 0.16773276972341536, 0.16292970180897998, 0.1624078173974071, 0.1581564053230247, 0.16138631771662798, 0.1613743634068902, 0.16117033383201715, 0.16435716815717916, 0.15261254508631614, 0.15830025586525756, 0.1586052661034935, 0.15065102412286266, 0.16349577796292997, 0.14565448447463641, 0.14965863993294776, 0.14736669204162922, 0.14092458027749125, 0.13651275910554636, 0.14863851541738854, 0.1403851879237084, 0.12991787579146308, 0.1292003040734406, 0.14170971262406423, 0.13283296721899587, 0.1315456115378579, 0.1263355142863282, 0.13766757375702748, 0.13268583247972804, 0.12985728354436654, 0.1273817187689347, 0.13667675894596323, 0.13421809592611894, 0.12650717670708994, 0.12325426335549451, 0.13547651560225518, 0.1298969334081375]

# Training rounds
n = 5

# Create a list of all rounds
all_rounds = np.arange(1, 101)

# Select specific rounds: 1, n, 2n, 3n, ..., 100
rounds = np.append(all_rounds[0], all_rounds[n-1::n])

# Update values to match new rounds
cl_losses = np.append(cl_losses[0], cl_losses[n-1::n])
client_losses = {key: np.append(values[0], values[n-1::n]) for key, values in client_losses.items()}
aggregated_losses = np.append(aggregated_losses[0], aggregated_losses[n-1::n])

plot_validation_losses(rounds, client_losses, aggregated_losses, cl_losses, 'val-loss-iid-all.png')

# %% [markdown]
# ## Plot performance metrics (precision, recall, accuracy, and F1)

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from matplotlib.lines import Line2D

def plot_validation_accuracies(rounds, fl_metrics, cl_metrics, filename):

    # Initialize list for lines and labels
    lines = []
    labels = []

    # Create a line plot for metric
    for i, (metric, values) in enumerate(fl_metrics.items()):
        line, = plt.plot(rounds
                         , values
                         , marker='x'
                         , color=color_palette[i]
#                          , markersize=6
#                          , markeredgewidth=2
                         , markerfacecolor='white'
#                          , markeredgecolor=color_palette[i]
                         , zorder=len(fl_metrics)-i  # setting zorder
                         , alpha=0.8
                         , linewidth=1)
        lines.append(line)
        if metric == "FL F1-score":
            labels.append('FL F$_1$-score')
        else:
            labels.append(metric.replace("_", "\_"))
        
    for i, (metric, values) in enumerate(cl_metrics.items()):
        line, = plt.plot(rounds
                         , values
                         , marker='o'
                         , color=color_palette[i]
#                          , markersize=6
#                          , markeredgewidth=2
                         , markerfacecolor='white'
#                          , markeredgecolor=color_palette[i]
                         , zorder=len(cl_metrics)-i  # setting zorder
                         , alpha=0.8
                         , linewidth=1)
        lines.append(line)
        if metric == "CL F1-score":
            labels.append('CL F$_1$-score')
        else:
            labels.append(metric.replace("_", "\_"))

    # Add title and labels
    plt.xlabel('Epochs')
    plt.ylabel('Metrics')

    # Add a legend
    plt.legend(lines, labels,
               bbox_to_anchor=(0., 1.02, 1., .102),
               loc='lower left',
               ncol=2,
               mode="expand",
               borderaxespad=0.,
               fancybox=True,
               shadow=True)

    plt.grid(linestyle='--', linewidth=0.5)

    # Set x ticks
    plt.xticks(rounds)

    # Show the plot
    plt.tight_layout()

    # Save the plot
    plt.savefig(filename, dpi=300, bbox_inches='tight')
    
    plt.show()

    # Clear the current plot to make ready for the next plot
    plt.clf()

# Set the font and color palette
sns.set_theme(style="whitegrid")
plt.rcParams['font.family'] = 'CMU Serif'
plt.rcParams['font.size'] = '14'
color_palette = sns.color_palette("bright")

fl_metrics = {
"FL Precision": [0.8043835296109442, 0.8164793507461956, 0.8492264052918487, 0.8510808197930331, 0.8587457412355843, 0.864068507887396, 0.8643192829122107, 0.8710222985630902, 0.8690202613202802, 0.8806719170380866, 0.8797371321790253, 0.8787852258536069, 0.8787301862973831, 0.8806409069539467, 0.8839673956861508, 0.8881614722825756, 0.8918163670056747, 0.8907435598820044, 0.8927447145154662, 0.8919108379797799, 0.8954442544096737, 0.8946745141535439, 0.8972213080362448, 0.8987787356904624, 0.897902516354701, 0.9005298191627218, 0.904643436307911, 0.8976694033126646, 0.9027542623837188, 0.9051429509785078, 0.9063579027935155, 0.9085016392588455, 0.9049793961233733, 0.9056229412996957, 0.905415723784071, 0.909628398726589, 0.9051690829325714, 0.9072136669244665, 0.9067743694690736, 0.8974904113885603, 0.9083207790180072, 0.9074302367839555, 0.9071527694365433, 0.9065418703195572, 0.9040402450785034, 0.905907489586169, 0.9086928457394261, 0.9085450752326129, 0.9086472398212987, 0.906243144542406, 0.9050626817259382, 0.9140553432885569, 0.9071816274538594, 0.9113351300351846, 0.914399621679858, 0.9050188382319054, 0.9131160652301342, 0.9123299197051989, 0.9113994279239515, 0.9134719044661971, 0.9120140976061527, 0.9127199350784505, 0.9125318612698996, 0.9124020322910018, 0.9116653212934753, 0.9136645971552758, 0.9177573831642313, 0.9164957150267546, 0.9150265851741525, 0.9167464226556098, 0.9147297356351011, 0.9137600026896954, 0.9209619196422172, 0.9134295376962682, 0.9143067551239438, 0.92252537488422, 0.9224113682968716, 0.9229392544542776, 0.9229453207395213, 0.9252937775488294, 0.9307812361625611, 0.9290545038337598, 0.9267944801464149, 0.9286481651907598, 0.9312075117645211, 0.9296402473497134, 0.9256662516981521, 0.934449671080302, 0.9352488446202697, 0.9339025638741355, 0.9285522861336192, 0.9317162677656033, 0.9354743035180367, 0.9356537740836947, 0.9288387796347873, 0.9363910268663374, 0.9348917339588497, 0.9352561081434706, 0.9320659294943153, 0.9346319132802817],
"FL Recall":  [0.8041416735441002, 0.8163086090405867, 0.8481998831263897, 0.8512939345864902, 0.8582846614806735, 0.8648034910880532, 0.8647601474439957, 0.8714897632831118, 0.8691241627172211, 0.881070812578286, 0.8787722692832103, 0.8786143184364051, 0.8802322295226482, 0.8814884396468889, 0.8834066688222403, 0.8874521619880862, 0.8897768872333897, 0.8907918377818486, 0.8913980813510033, 0.8913702193013697, 0.8969730150885716, 0.8952519105035684, 0.8975640591642947, 0.899191411355444, 0.8980952201178408, 0.898394119143343, 0.9040130309472876, 0.8983576493818836, 0.9018134328038898, 0.9048355722085517, 0.9044117920221347, 0.9079547986765809, 0.9046844110012117, 0.9058132139080932, 0.9049297168820509, 0.9098785033128705, 0.9069276039680825, 0.906812114542099, 0.9075022246636131, 0.896909273482155, 0.9067667879549621, 0.9071466237834521, 0.9067844961262668, 0.9054824497786874, 0.9055120050973595, 0.9045438403077287, 0.9083157507365914, 0.9089128213631248, 0.9081288257630512, 0.9056169919596381, 0.9039584534560599, 0.9148303472673509, 0.9089374451934791, 0.9092194427717356, 0.9149735796485894, 0.9045620468803596, 0.9146589348409772, 0.9139049856567647, 0.9123107915643761, 0.9126925571939876, 0.913015350305171, 0.9128655708960844, 0.9113639599849819, 0.9113464206741212, 0.9103566583188473, 0.9151479532617695, 0.9164322759184634, 0.9180189812430869, 0.9131804578155301, 0.9157403128180609, 0.9158558072819893, 0.9138215058643074, 0.9210105143650474, 0.9141203727664011, 0.9125969555879342, 0.9225299670917497, 0.9219514982589307, 0.9233585406018402, 0.9212084097385155, 0.9257257808562599, 0.9321139247545422, 0.9288706143678653, 0.9285220355694986, 0.9279331566091475, 0.9302759455645594, 0.931026919032852, 0.926620024473408, 0.9328527925916417, 0.9351588791473353, 0.9344235192119511, 0.9293257833017604, 0.9314424780406854, 0.9368352156866079, 0.9376238000001974, 0.9309580372276511, 0.9371823547325562, 0.9344893615102808, 0.935463176283474, 0.9319754366446726, 0.9334731867541032],
"FL Accuracy":  [0.8056067362662552, 0.8182520108894085, 0.8498025329320529, 0.8535119694318641, 0.8593967207023724, 0.8658739606057677, 0.8652309453571633, 0.873274781531313, 0.8697094073325201, 0.8832644200718002, 0.880397412377994, 0.8794524597774738, 0.8812529179977724, 0.8828060704966424, 0.8850122264503493, 0.8897727729367494, 0.8923072300604845, 0.8916082701424768, 0.8933831723388199, 0.8928556360850668, 0.8978071387183167, 0.8967421648096351, 0.8992421018808089, 0.901196272276938, 0.9003090714076101, 0.9009996082184258, 0.9063189210956079, 0.8990624162838805, 0.9033182602973451, 0.9070475167895137, 0.90686528908533, 0.9095401118845597, 0.9061709501629464, 0.9079524485018127, 0.9068646527860952, 0.9111377980971315, 0.9075745820553655, 0.9081036943726111, 0.9080854956453, 0.8991314739190374, 0.9092284484420368, 0.9097789212269641, 0.909272264726325, 0.9076385719630264, 0.9062304728278073, 0.9065769139102713, 0.9092037109942075, 0.9099320254947405, 0.909944646188382, 0.9078396728223239, 0.9059002104429096, 0.9161957399686335, 0.9095747624796845, 0.9119277117864006, 0.9159995729108386, 0.9060648639548425, 0.9157951529814836, 0.914788610942184, 0.9132026113038287, 0.914949673619345, 0.9142179664781036, 0.9136506045047166, 0.9137031493625484, 0.913498054570523, 0.9121299428478438, 0.9160260880502594, 0.9182894350006299, 0.9188866395131404, 0.9156400984198774, 0.9178047092480334, 0.9170836159681258, 0.9145474413513813, 0.9226149239205355, 0.9160287464316208, 0.9149750420314285, 0.9234611309284337, 0.9240141745106556, 0.9251072613844541, 0.9236752843042344, 0.9280399986965333, 0.9327887469343837, 0.929606614214487, 0.9291207148420113, 0.9296789878651396, 0.9329900488687973, 0.9316118432883718, 0.9281389709337774, 0.9355174333958036, 0.9377210798559505, 0.9361874379052987, 0.930369646495381, 0.9341519961589744, 0.9376333182050041, 0.9381019128171136, 0.9316279477834126, 0.9383576319529837, 0.9365558828143594, 0.9379745269434691, 0.933766603000873, 0.9359973309242589],
"FL F1-score":   [0.8042625833949171, 0.8163939709661051, 0.8487128338133856, 0.8511873638501856, 0.8585151394505063, 0.8644358432586037, 0.8645396589743419, 0.8712559682195854, 0.8690722089132837, 0.8808713196490239, 0.8792544360295452, 0.8786997638346177, 0.8794805665848144, 0.8810644694811957, 0.8836869433045436, 0.8878066754600575, 0.8907954597717855, 0.8907676981777841, 0.8920708897281505, 0.8916404466937178, 0.8962079828057238, 0.8949631191999949, 0.897392650872586, 0.8989850261636562, 0.8979988578980784, 0.899460701391101, 0.9043281237640277, 0.898013394477698, 0.9022836023383061, 0.9049892354933007, 0.9053838016240501, 0.9082281366550807, 0.9048318795201964, 0.905718067610811, 0.9051726550961444, 0.9097534338303737, 0.9060474901856378, 0.9070128462895055, 0.9071381510651256, 0.8971997483311095, 0.9075431182601154, 0.9072884081197669, 0.906968595397193, 0.9060118503480136, 0.9047755265759092, 0.9052251513901015, 0.9085042591075827, 0.9087289110928207, 0.908387958827876, 0.9059299600563967, 0.9045102305799911, 0.9144426810710902, 0.9080586875643613, 0.9102760570712931, 0.9146865106258024, 0.9047903849023573, 0.9138868488485561, 0.9131167734603777, 0.9118548820260547, 0.9130820645301277, 0.9125144493006505, 0.9127927471782293, 0.9119475367043813, 0.9118739209810315, 0.9110105198341191, 0.9144056736309202, 0.9170943508805928, 0.9172567157224438, 0.9141025893831756, 0.9162430915392002, 0.9152924251110721, 0.9137907532421253, 0.920986216362622, 0.9137748246594988, 0.9134510552550809, 0.9225276709822702, 0.9221813759463273, 0.9231488499190346, 0.9220760472866494, 0.9255097287906361, 0.9314471037653592, 0.9289625500005169, 0.9276574535618395, 0.9282905232175193, 0.9307414955666897, 0.9303330664792151, 0.926142892529108, 0.9336505490272258, 0.9352038597201603, 0.934162968912664, 0.928938873701238, 0.931579352786551, 0.9361542650040972, 0.9366377511564571, 0.929897200973312, 0.9367865236856849, 0.9346905044305039, 0.9353596307533845, 0.9320206808729344, 0.9340521906564793]
}

cl_metrics = {
"CL Precision": [0.9231134563096338, 0.9411722920721302, 0.9445184948345234, 0.9493429038493282, 0.9508729506299594, 0.9517576111178961, 0.9530050546067741, 0.9536395165017961, 0.9546363803004381, 0.9548400418201213, 0.9557091636407682, 0.9539415277664258, 0.9508141133881057, 0.9521879466636534, 0.9522337412575178, 0.9515996836785592, 0.9556128154508201, 0.9531603231679989, 0.9564692515248, 0.9580469017985347, 0.9585084529983531, 0.9588040343754247, 0.9576873729801175, 0.9588381864237092, 0.9601380317942081, 0.9599766946476231, 0.9601963293501523, 0.9598317821143935, 0.9598452755466328, 0.9595805180152264, 0.9591796361628283, 0.9588639548212381, 0.9587431982089312, 0.9589520318094358, 0.9589715026381626, 0.958402312158713, 0.9587997943696538, 0.9582693354472406, 0.9610516641518785, 0.9594130846338411, 0.9625784648234286, 0.9610189952064065, 0.9602410187305088, 0.9617647865987999, 0.9616510306323015, 0.9625832625835656, 0.9600362707620361, 0.9625300836361184, 0.9589422066403566, 0.9603093249871334, 0.9598311838091137, 0.9601985441223088, 0.9602743640524822, 0.9602181377559837, 0.959861880953653, 0.9607990403970806, 0.9588332189903029, 0.9597109646402219, 0.9615148207030717, 0.9621899389831094, 0.9622384890377343, 0.9618184334600073, 0.962073568979059, 0.9613932878671273, 0.9615430786140925, 0.961605360174118, 0.9614904166792411, 0.9620195794285348, 0.9614372230104282, 0.9609535352113167, 0.9602691003238423, 0.9617903000572549, 0.9623808401132221, 0.9630785845445733, 0.962550459587235, 0.9609511361049892, 0.9631288276837806, 0.9643685418239679, 0.9625783834881754, 0.9640177735189506, 0.9624406098979351, 0.9633649303084966, 0.9645531650321025, 0.9634864324222876, 0.963239042830508, 0.9642522246595453, 0.9649080939753037, 0.9642376870439759, 0.9649530839777342, 0.965757136209691, 0.9661157531049239, 0.9667843477145505, 0.9664742431793119, 0.964337342803194, 0.9662499976449901, 0.9659590623175648, 0.9662109380962933, 0.964331773286913, 0.9644466972371462, 0.966378499534982],
"CL Recall":  [0.9268904212083191, 0.9363602038459813, 0.9414045096367593, 0.9436934453277269, 0.9461585539399657, 0.9465039469883898, 0.9487328661351777, 0.9494697782569513, 0.9515027616764462, 0.9511402390040926, 0.953420104428434, 0.95351663638168, 0.9537307741811208, 0.954909032903027, 0.9546280988396928, 0.9545719907012888, 0.9550724808369425, 0.9557508731281914, 0.9562341938202389, 0.9560616703789183, 0.9564628888656461, 0.9564277415851015, 0.9576772608222412, 0.9557573380315072, 0.9581283673219989, 0.957402852299811, 0.9593824797679327, 0.9584709537649141, 0.9588631541661551, 0.9595042121095618, 0.9596981732420824, 0.9589790926608226, 0.9595816214733723, 0.9599929142616643, 0.959757360321088, 0.9601058261498574, 0.9601790713834258, 0.9601199391690581, 0.9606659934982146, 0.9599113753461161, 0.9616328089837769, 0.9605236795421073, 0.9611998243579922, 0.9616546184306444, 0.9614249290053338, 0.9618371109285835, 0.9610517547462051, 0.9612211579979766, 0.9608802953995392, 0.96200256106269, 0.9618010485425916, 0.9620898766794006, 0.9624536363890526, 0.9627082721140228, 0.963023672671194, 0.9633564133693749, 0.962920667576755, 0.9631554085234836, 0.963993786366054, 0.9643354493245291, 0.9643990046692368, 0.9636822716978749, 0.963766928821066, 0.9639077921480892, 0.9633676467045559, 0.9633888957531825, 0.9633358396934728, 0.9638679115973433, 0.9634853314996373, 0.9637087716610042, 0.9635979909828635, 0.9644897780015175, 0.9641046673351917, 0.9638048449329185, 0.9646120503466076, 0.9638266497728329, 0.9638170380082881, 0.9634561146943005, 0.9634869552616369, 0.9645833539190664, 0.964604736784875, 0.964668009752981, 0.9651926955263062, 0.9644337633893899, 0.9652386214835573, 0.9652159755222925, 0.9638458946308657, 0.9646858224819033, 0.9652363535967214, 0.96555808227978, 0.9664251719383617, 0.9663793623752165, 0.9662863892925164, 0.9656135496013525, 0.966165645156407, 0.9663380920150295, 0.9662058089348559, 0.9659836749278984, 0.9653207645520367, 0.9660855749427466],   
"CL Accuracy":  [0.9210447392562275, 0.9317841013337097, 0.9368163855761767, 0.9398154682097241, 0.941681074024416, 0.9424440759297156, 0.9451211982217204, 0.9466913061886952, 0.9483584432996965, 0.9481423329334556, 0.9499373720979465, 0.949716851316068, 0.9488744619292923, 0.9500299908263354, 0.9504533907275422, 0.9502284595300261, 0.9514589654929081, 0.9510223343447887, 0.9520587820196176, 0.9530423047067955, 0.9531525650977348, 0.9532495942417614, 0.9534921671018277, 0.9530511255380707, 0.9544007127231671, 0.9548152917930985, 0.9555518312045728, 0.9553489520852445, 0.9557811728177263, 0.9560237456777927, 0.9561781102251076, 0.9559311269494037, 0.956111953990544, 0.9564118622538988, 0.9563765789287982, 0.9562266247971208, 0.956266318537859, 0.9565706372168513, 0.957558570319667, 0.9569411121304072, 0.9584053701220803, 0.9572542516406746, 0.957404205772352, 0.95822454308094, 0.9581804389245643, 0.9585068096817444, 0.9576114953073178, 0.9583700867969798, 0.9572718933032249, 0.9582333639122151, 0.9579025827393973, 0.9580613577023499, 0.9583083409780537, 0.958480347187919, 0.9584230117846306, 0.9590713428833533, 0.9583215722249665, 0.9587140992167101, 0.9600151718297932, 0.9601077905581822, 0.9601122009738198, 0.9600901488956319, 0.9600989697269071, 0.9599622468421424, 0.9597858302166397, 0.9598343447886529, 0.9600504551548938, 0.9603812363277116, 0.9600107614141556, 0.9600151718297932, 0.9596711594100628, 0.9602489238585844, 0.9604385717309999, 0.9606502716816033, 0.9605620633688519, 0.9600372239079811, 0.9604606238091877, 0.960826688307106, 0.9602930280149601, 0.9611177757391857, 0.9606193987721403, 0.960950179944958, 0.9617043610189824, 0.9612192152988498, 0.961483840237104, 0.9618499047350222, 0.9612721402865007, 0.9616823089407945, 0.9620527838543504, 0.962312998376967, 0.9627981440970997, 0.9629348669818644, 0.9630230752946157, 0.9620351421918002, 0.9628554795003881, 0.9628378378378378, 0.9625423399901206, 0.9622512525580411, 0.9618322630724719, 0.9625952649777715],
"CL F1-score":   [0.924785861776166, 0.9386555188275567, 0.9428054947206175, 0.946355758761538, 0.9483925749749387, 0.9489607476448612, 0.9507292760944461, 0.9514028460570014, 0.9529223415792731, 0.9528266661914169, 0.9544324988091404, 0.9535255060733926, 0.951910783849556, 0.9532322465156773, 0.9530774991173109, 0.9526581410667679, 0.9550850337734967, 0.9541004027256859, 0.956133008538151, 0.9568639899314295, 0.9572789687526075, 0.9574028461839885, 0.9574599545704642, 0.9570235835470754, 0.9588983173095784, 0.9584444784153417, 0.9596083093875339, 0.9589609918146763, 0.9591726047695177, 0.9593458863517131, 0.9592323843146208, 0.958718193943499, 0.9589325772838725, 0.9592705417244325, 0.9591806463944698, 0.9590015302100001, 0.9593314979638305, 0.9589793183744926, 0.9607077485355289, 0.959488809492988, 0.9619957332216776, 0.9606058642803527, 0.9605279828910088, 0.9615587113806182, 0.9614059224075573, 0.9620631074079959, 0.9603589469227003, 0.9617454543516635, 0.9597031794509668, 0.9609439616888189, 0.9605920309296163, 0.960922907661752, 0.961147204256563, 0.9612439157375208, 0.9612191303618957, 0.9618844710860881, 0.9605997624918402, 0.961202303949358, 0.9626067865957687, 0.9631053401981386, 0.9631647938062985, 0.962573167949573, 0.9627856803225384, 0.9624638664513187, 0.9622624746227496, 0.9623096406094813, 0.9622328989307036, 0.9627784483287092, 0.9622747712508956, 0.9621276690935547, 0.9616951115696679, 0.9629377985554145, 0.9630703094299007, 0.963290938943041, 0.9634223890831951, 0.9622041617402626, 0.9633001723600649, 0.9637428027916645, 0.962860544200764, 0.9641900909258704, 0.9633603341015909, 0.9638860623818666, 0.9647415616786539, 0.96379398139865, 0.9640993678773484, 0.9645925372674666, 0.9642010175437342, 0.9643137692947068, 0.9649707568652456, 0.9655639527246741, 0.9661705020020307, 0.9665046322381501, 0.9662929288634491, 0.9648469942464988, 0.9661157558885473, 0.9660483951530686, 0.966106135304449, 0.9650314818245975, 0.9647332475683298, 0.966131372234261]
}

# Training rounds
n = 5

# Create a list of all rounds
all_rounds = np.arange(1, 101)

# Select specific rounds: 1, n, 2n, 3n, ..., 100
rounds = np.append(all_rounds[0], all_rounds[n-1::n])

# Update values to match new rounds
fl_metrics = {key: np.append(values[0], values[n-1::n]) for key, values in fl_metrics.items()}
cl_metrics = {key: np.append(values[0], values[n-1::n]) for key, values in cl_metrics.items()}

plot_validation_accuracies(rounds, fl_metrics, cl_metrics, 'mpm-iid-all.png')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Set the font family and size
plt.rcParams['font.family'] = 'CMU Serif'
plt.rcParams['font.size'] = 12

# Set the Seaborn color palette
sns.set_palette('tab10')

# IID FL results
fl_precision_iid = np.array([0.8043835296109442, 0.8164793507461956, 0.8492264052918487, 0.8510808197930331, 0.8587457412355843, 0.864068507887396, 0.8643192829122107, 0.8710222985630902, 0.8690202613202802, 0.8806719170380866, 0.8797371321790253, 0.8787852258536069, 0.8787301862973831, 0.8806409069539467, 0.8839673956861508, 0.8881614722825756, 0.8918163670056747, 0.8907435598820044, 0.8927447145154662, 0.8919108379797799, 0.8954442544096737, 0.8946745141535439, 0.8972213080362448, 0.8987787356904624, 0.897902516354701, 0.9005298191627218, 0.904643436307911, 0.8976694033126646, 0.9027542623837188, 0.9051429509785078, 0.9063579027935155, 0.9085016392588455, 0.9049793961233733, 0.9056229412996957, 0.905415723784071, 0.909628398726589, 0.9051690829325714, 0.9072136669244665, 0.9067743694690736, 0.8974904113885603, 0.9083207790180072, 0.9074302367839555, 0.9071527694365433, 0.9065418703195572, 0.9040402450785034, 0.905907489586169, 0.9086928457394261, 0.9085450752326129, 0.9086472398212987, 0.906243144542406, 0.9050626817259382, 0.9140553432885569, 0.9071816274538594, 0.9113351300351846, 0.914399621679858, 0.9050188382319054, 0.9131160652301342, 0.9123299197051989, 0.9113994279239515, 0.9134719044661971, 0.9120140976061527, 0.9127199350784505, 0.9125318612698996, 0.9124020322910018, 0.9116653212934753, 0.9136645971552758, 0.9177573831642313, 0.9164957150267546, 0.9150265851741525, 0.9167464226556098, 0.9147297356351011, 0.9137600026896954, 0.9209619196422172, 0.9134295376962682, 0.9143067551239438, 0.92252537488422, 0.9224113682968716, 0.9229392544542776, 0.9229453207395213, 0.9252937775488294, 0.9307812361625611, 0.9290545038337598, 0.9267944801464149, 0.9286481651907598, 0.9312075117645211, 0.9296402473497134, 0.9256662516981521, 0.934449671080302, 0.9352488446202697, 0.9339025638741355, 0.9285522861336192, 0.9317162677656033, 0.9354743035180367, 0.9356537740836947, 0.9288387796347873, 0.9363910268663374, 0.9348917339588497, 0.9352561081434706, 0.9320659294943153, 0.9346319132802817])
fl_recall_iid = np.array([0.8041416735441002, 0.8163086090405867, 0.8481998831263897, 0.8512939345864902, 0.8582846614806735, 0.8648034910880532, 0.8647601474439957, 0.8714897632831118, 0.8691241627172211, 0.881070812578286, 0.8787722692832103, 0.8786143184364051, 0.8802322295226482, 0.8814884396468889, 0.8834066688222403, 0.8874521619880862, 0.8897768872333897, 0.8907918377818486, 0.8913980813510033, 0.8913702193013697, 0.8969730150885716, 0.8952519105035684, 0.8975640591642947, 0.899191411355444, 0.8980952201178408, 0.898394119143343, 0.9040130309472876, 0.8983576493818836, 0.9018134328038898, 0.9048355722085517, 0.9044117920221347, 0.9079547986765809, 0.9046844110012117, 0.9058132139080932, 0.9049297168820509, 0.9098785033128705, 0.9069276039680825, 0.906812114542099, 0.9075022246636131, 0.896909273482155, 0.9067667879549621, 0.9071466237834521, 0.9067844961262668, 0.9054824497786874, 0.9055120050973595, 0.9045438403077287, 0.9083157507365914, 0.9089128213631248, 0.9081288257630512, 0.9056169919596381, 0.9039584534560599, 0.9148303472673509, 0.9089374451934791, 0.9092194427717356, 0.9149735796485894, 0.9045620468803596, 0.9146589348409772, 0.9139049856567647, 0.9123107915643761, 0.9126925571939876, 0.913015350305171, 0.9128655708960844, 0.9113639599849819, 0.9113464206741212, 0.9103566583188473, 0.9151479532617695, 0.9164322759184634, 0.9180189812430869, 0.9131804578155301, 0.9157403128180609, 0.9158558072819893, 0.9138215058643074, 0.9210105143650474, 0.9141203727664011, 0.9125969555879342, 0.9225299670917497, 0.9219514982589307, 0.9233585406018402, 0.9212084097385155, 0.9257257808562599, 0.9321139247545422, 0.9288706143678653, 0.9285220355694986, 0.9279331566091475, 0.9302759455645594, 0.931026919032852, 0.926620024473408, 0.9328527925916417, 0.9351588791473353, 0.9344235192119511, 0.9293257833017604, 0.9314424780406854, 0.9368352156866079, 0.9376238000001974, 0.9309580372276511, 0.9371823547325562, 0.9344893615102808, 0.935463176283474, 0.9319754366446726, 0.9334731867541032])
fl_accuracy_iid = np.array([0.8056067362662552, 0.8182520108894085, 0.8498025329320529, 0.8535119694318641, 0.8593967207023724, 0.8658739606057677, 0.8652309453571633, 0.873274781531313, 0.8697094073325201, 0.8832644200718002, 0.880397412377994, 0.8794524597774738, 0.8812529179977724, 0.8828060704966424, 0.8850122264503493, 0.8897727729367494, 0.8923072300604845, 0.8916082701424768, 0.8933831723388199, 0.8928556360850668, 0.8978071387183167, 0.8967421648096351, 0.8992421018808089, 0.901196272276938, 0.9003090714076101, 0.9009996082184258, 0.9063189210956079, 0.8990624162838805, 0.9033182602973451, 0.9070475167895137, 0.90686528908533, 0.9095401118845597, 0.9061709501629464, 0.9079524485018127, 0.9068646527860952, 0.9111377980971315, 0.9075745820553655, 0.9081036943726111, 0.9080854956453, 0.8991314739190374, 0.9092284484420368, 0.9097789212269641, 0.909272264726325, 0.9076385719630264, 0.9062304728278073, 0.9065769139102713, 0.9092037109942075, 0.9099320254947405, 0.909944646188382, 0.9078396728223239, 0.9059002104429096, 0.9161957399686335, 0.9095747624796845, 0.9119277117864006, 0.9159995729108386, 0.9060648639548425, 0.9157951529814836, 0.914788610942184, 0.9132026113038287, 0.914949673619345, 0.9142179664781036, 0.9136506045047166, 0.9137031493625484, 0.913498054570523, 0.9121299428478438, 0.9160260880502594, 0.9182894350006299, 0.9188866395131404, 0.9156400984198774, 0.9178047092480334, 0.9170836159681258, 0.9145474413513813, 0.9226149239205355, 0.9160287464316208, 0.9149750420314285, 0.9234611309284337, 0.9240141745106556, 0.9251072613844541, 0.9236752843042344, 0.9280399986965333, 0.9327887469343837, 0.929606614214487, 0.9291207148420113, 0.9296789878651396, 0.9329900488687973, 0.9316118432883718, 0.9281389709337774, 0.9355174333958036, 0.9377210798559505, 0.9361874379052987, 0.930369646495381, 0.9341519961589744, 0.9376333182050041, 0.9381019128171136, 0.9316279477834126, 0.9383576319529837, 0.9365558828143594, 0.9379745269434691, 0.933766603000873, 0.9359973309242589])
fl_f1_iid = np.array([0.8042625833949171, 0.8163939709661051, 0.8487128338133856, 0.8511873638501856, 0.8585151394505063, 0.8644358432586037, 0.8645396589743419, 0.8712559682195854, 0.8690722089132837, 0.8808713196490239, 0.8792544360295452, 0.8786997638346177, 0.8794805665848144, 0.8810644694811957, 0.8836869433045436, 0.8878066754600575, 0.8907954597717855, 0.8907676981777841, 0.8920708897281505, 0.8916404466937178, 0.8962079828057238, 0.8949631191999949, 0.897392650872586, 0.8989850261636562, 0.8979988578980784, 0.899460701391101, 0.9043281237640277, 0.898013394477698, 0.9022836023383061, 0.9049892354933007, 0.9053838016240501, 0.9082281366550807, 0.9048318795201964, 0.905718067610811, 0.9051726550961444, 0.9097534338303737, 0.9060474901856378, 0.9070128462895055, 0.9071381510651256, 0.8971997483311095, 0.9075431182601154, 0.9072884081197669, 0.906968595397193, 0.9060118503480136, 0.9047755265759092, 0.9052251513901015, 0.9085042591075827, 0.9087289110928207, 0.908387958827876, 0.9059299600563967, 0.9045102305799911, 0.9144426810710902, 0.9080586875643613, 0.9102760570712931, 0.9146865106258024, 0.9047903849023573, 0.9138868488485561, 0.9131167734603777, 0.9118548820260547, 0.9130820645301277, 0.9125144493006505, 0.9127927471782293, 0.9119475367043813, 0.9118739209810315, 0.9110105198341191, 0.9144056736309202, 0.9170943508805928, 0.9172567157224438, 0.9141025893831756, 0.9162430915392002, 0.9152924251110721, 0.9137907532421253, 0.920986216362622, 0.9137748246594988, 0.9134510552550809, 0.9225276709822702, 0.9221813759463273, 0.9231488499190346, 0.9220760472866494, 0.9255097287906361, 0.9314471037653592, 0.9289625500005169, 0.9276574535618395, 0.9282905232175193, 0.9307414955666897, 0.9303330664792151, 0.926142892529108, 0.9336505490272258, 0.9352038597201603, 0.934162968912664, 0.928938873701238, 0.931579352786551, 0.9361542650040972, 0.9366377511564571, 0.929897200973312, 0.9367865236856849, 0.9346905044305039, 0.9353596307533845, 0.9320206808729344, 0.9340521906564793])

# CL results
cl_results = np.array([0.966378499534982, 0.9660855749427466, 0.9625952649777715, 0.966131372234261])

metrics = ["Precision", "Recall", "Accuracy", "F1"]

def plot_graph(fl_precision, fl_recall, fl_accuracy, fl_f1, plot_name):
    fl_min = [fl_precision.min(), fl_recall.min(), fl_accuracy.min(), fl_f1.min()]
    fl_max = [fl_precision.max(), fl_recall.max(), fl_accuracy.max(), fl_f1.max()]
    fl_final = [fl_precision[-1], fl_recall[-1], fl_accuracy[-1], fl_f1[-1]]

    x = np.arange(len(metrics))

    fig, ax = plt.subplots(figsize=(8, 5.6))

    bar_width = 0.20
    opacity = 0.8
    hatch_patterns = ['//', '\\\\', '++', 'xx']

    rects1 = ax.bar(x - bar_width, fl_min, bar_width, alpha=opacity, label='FL Min', hatch=hatch_patterns[0])
    rects2 = ax.bar(x, fl_max, bar_width, alpha=opacity, label='FL Max', hatch=hatch_patterns[1])
    rects3 = ax.bar(x + bar_width, fl_final, bar_width, alpha=opacity, label='FL Final', hatch=hatch_patterns[2])
    rects4 = ax.bar(x + 2*bar_width, cl_results, bar_width, alpha=opacity, label='CL Result', hatch=hatch_patterns[3])

    # Adding labels
    ax.set_xlabel('Metrics', labelpad=20)
    ax.set_ylabel('Values', labelpad=20)
    ax.set_xticks(x)
    ax.set_xticklabels(metrics)
    ax.set_ylim(0, 1.1)  # Increase y-axis limit

    # Set the legend
    ax.legend(loc='lower left', bbox_to_anchor=(0., 1.02, 1., .102), fancybox=True, shadow=True, ncol=2, mode="expand", borderaxespad=0.)

    ax.grid(axis='y', linestyle='--', alpha=0.6)

    # Function to attach a label above each bar in rects
    def autolabel(rects):
        for rect in rects:
            height = rect.get_height()
            ax.annotate('{:.2f}'.format(height),
                        xy=(rect.get_x() + rect.get_width() / 2, height),
                        xytext=(0, 3),  # Offset label by 3 points above bar
                        textcoords="offset points",
                        ha='center', va='bottom')

    autolabel(rects1)
    autolabel(rects2)
    autolabel(rects3)
    autolabel(rects4)

    fig.tight_layout()
    plt.savefig(plot_name, dpi=300, bbox_inches='tight')
    plt.show()
    plt.close()

plot_graph(fl_precision_iid, fl_recall_iid, fl_accuracy_iid, fl_f1_iid, 'mpm-iid.png')

# %% [markdown]
# ## Plot the normalized confusion matrix

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Define the labels for our axes
labels = ["QUIC.YouTube", "TLS.TikTok", "TLS.Apple", "Discord", "BitTorrent",
         "QUIC.Facebook", "STUN", "HTTP", "SSH", "WhatsApp"]


# Define the confusion matrix
fl_iid_confusion = np.array([
            [9.459e-01, 0.000e+00, 0.000e+00, 1.710e-02, 1.300e-02, 2.340e-02, 4.000e-04, 1.000e-04, 0.000e+00, 0.000e+00],
            [1.000e-04, 8.903e-01, 4.770e-02, 5.000e-04, 4.000e-04, 1.100e-03, 2.000e-04, 2.950e-02, 2.060e-02, 9.500e-03],
            [0.000e+00, 8.480e-02, 9.015e-01, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 9.700e-03, 3.100e-03, 7.000e-04],
            [6.000e-04, 0.000e+00, 0.000e+00, 9.756e-01, 5.000e-03, 1.600e-03, 1.730e-02, 0.000e+00, 0.000e+00, 0.000e+00],
            [1.800e-03, 3.000e-04, 0.000e+00, 1.060e-02, 9.629e-01, 1.030e-02, 1.270e-02, 1.200e-03, 0.000e+00, 0.000e+00],
            [2.380e-02, 0.000e+00, 0.000e+00, 4.100e-03, 2.140e-02, 9.297e-01, 2.090e-02, 1.000e-04, 0.000e+00, 0.000e+00],
            [2.900e-03, 0.000e+00, 0.000e+00, 1.640e-02, 5.930e-02, 1.560e-02, 9.057e-01, 1.000e-04, 0.000e+00, 0.000e+00],
            [0.000e+00, 7.020e-02, 2.040e-02, 1.800e-03, 3.700e-03, 2.000e-04, 4.300e-03, 8.966e-01, 1.100e-03, 1.700e-03],
            [0.000e+00, 6.910e-02, 3.500e-03, 0.000e+00, 3.500e-03, 0.000e+00, 0.000e+00, 1.800e-03, 9.220e-01, 0.000e+00],
            [0.000e+00, 9.900e-03, 1.800e-03, 1.000e-04, 0.000e+00, 0.000e+00, 8.000e-04, 4.500e-03, 4.690e-02, 9.362e-01]
        ])

FSIZE = 14

# Set the font family and size
plt.rcParams['font.family'] = 'CMU Serif'
plt.rcParams['font.size'] = FSIZE

cmap = sns.color_palette("Blues", as_cmap=True)

# Function to plot a confusion matrix
def plot_confusion_matrix(confusion_matrix, plot_name):
    fig, ax = plt.subplots(figsize=(12, 10))

    heatmap = sns.heatmap(confusion_matrix
                          , annot=True
                          , fmt=".4f"
                          , linewidths=.5
                          , ax=ax
                          , cmap=cmap
                          , cbar=True
                          , rasterized=False
                          )
    
    cbar = heatmap.collections[0].colorbar
    cbar.ax.tick_params(labelsize=FSIZE)

    for spine in ax.spines.values():
        spine.set(visible=True, lw=.8, edgecolor="black")

    # Set up axes
    ax.set_xticklabels(labels, rotation=45, ha='center', fontsize=FSIZE)  # Rotate the x-axis tick labels by 45 degrees
    ax.set_yticklabels(labels, rotation=45, ha='right', fontsize=FSIZE)  # Rotate the y-axis tick labels by 45 degrees
    ax.set_xlabel('Predictions', fontsize=FSIZE)
    ax.set_ylabel('Actuals', fontsize=FSIZE)

        
    # Move the x-axis tick labels to the top
#     ax.xaxis.set_tick_params(labeltop=True, labelbottom=False)
    ax.xaxis.set_tick_params(labeltop=False, labelbottom=False)

    # Move the x-axis ticks to the top
#     ax.tick_params(axis='x', which='both', top=True, bottom=False)
    ax.tick_params(axis='x', which='both', top=False, bottom=False)
    
    # Show the plot
    plt.savefig(plot_name, dpi=300, bbox_inches='tight')
    plt.show()

plot_confusion_matrix(fl_iid_confusion, "cm-iid.png")
